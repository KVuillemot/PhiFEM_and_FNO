# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import os

os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import tensorflow as tf

seed = 2023
random.seed(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.experimental.numpy.random.seed(seed)
os.environ["TF_CUDNN_DETERMINISTIC"] = "1"
os.environ["TF_DETERMINISTIC_OPS"] = "1"
# Set a fixed value for the hash seed
os.environ["PYTHONHASHSEED"] = str(seed)
import dolfin as df
import time
from utils import *
from utils_training import *
import prepare_data
import seaborn as sns
from mpl_toolkits.axes_grid1 import make_axes_locatable
import pandas as pd

sns.set_theme()
sns.set_context("paper")
sns.set(rc={"xtick.bottom": True, "ytick.left": True})
colors = sns.color_palette("mako").as_hex()
my_cmap = sns.color_palette("viridis", as_cmap=True)

# gpus = tf.config.list_physical_devices('GPU')
# if gpus:
#     for gpu in gpus:
#         tf.config.experimental.set_virtual_device_configuration(gpu,[tf.config.experimental.VirtualDeviceConfiguration(memory_limit=4096)])
# Out:
# Invalid MIT-MAGIC-COOKIE-1 key

# %%
nb_data = 1500
save_figs = True

small_data = False  # False=>on utilise toutes les données
level = 2
data = DataLoader(small_data)
agent = Agent(data, small_data)

if not (os.path.exists(f"./images_{nb_data}/")) and save_figs:
    os.makedirs(f"./images_{nb_data}/")

epochs = [100, 200, 500, 750, 1000, 1250, 1500, 2000]
print(len(epochs))
print(epochs)

indices = list(range(0, len(epochs)))
size_per_fig = 4
nb_rows = 2
size_row = int(len(indices) / nb_rows)
# Out:
# max_norm_F : 65.84134
# data_size,nb_val,nb_train: 1500 187 1313
# data shape: (None, 64, 64, 9)
# on val data: residues_interior =  1.7094484e-05
# modèle FNO2d crée avec comme hyperparamètre: modes:20, width:20, pad_prop:0.05
# 8
# [100, 200, 500, 750, 1000, 1250, 1500, 2000]

# %% [markdown]
# # Erreur minimale d'un modèle sur le jeu de validation

# %%
i = 2000
agent.model.load_weights(f"./models_{nb_data}/model_{i}/model_weights")
X_val, Y_val = agent.data.X_val, agent.data.Y_val
Y_pred = agent.model.call(X_val)
domain = X_val[:, :, :, -2]
boundary = X_val[:, :, :, -1]
nb_vert = np.shape(boundary)[1]
domain_prop = tf.reduce_sum(domain, axis=[1, 2]) / nb_vert**2
boundary_prop = tf.reduce_sum(boundary, axis=[1, 2]) / nb_vert**2

diff = (
    Y_val * X_val[:, :, :, 1, None]
    + X_val[:, :, :, 2, None]
    - (Y_pred * X_val[:, :, :, 1, None] + X_val[:, :, :, 2, None])
)

L2_error = tf.sqrt(
    tf.reduce_mean(
        (diff**2)
        * X_val[:, :, :, -2, None]
        / (domain_prop[:, None, None, None]),
        axis=[1, 2, 3],
    )
    / tf.reduce_mean(
        ((Y_val * X_val[:, :, :, 1, None] + X_val[:, :, :, 2, None]) ** 2)
        * X_val[:, :, :, -2, None]
        / (domain_prop[:, None, None, None]),
        axis=[1, 2, 3],
    )
)

argmin = np.argmin(L2_error)
print(argmin)
sorted_min = sorted(range(len(L2_error)), key=lambda k: L2_error[k])
minimal_errors = sorted_min[:1]
print(minimal_errors)


Params = np.load(f"./data_{nb_data}/agentParams.npy")
data_size = np.shape(Params)[0]
nb_val = data_size // 8
nb_train = data_size - nb_val
params_val = Params[nb_train:]


for i in minimal_errors:
    X = data.X_val[i, :, :]
    F = X[:, :, 0] * data.max_norm_F
    W_ref = data.Y_val[i]
    Y = agent.model.call(X[None, :, :, :])
    domains_nan = X[:, :, -2].numpy()
    domains_nan[domains_nan == 0] = np.nan

    plt.figure(figsize=(12, 4))

    ax1 = plt.subplot(131)
    img = ax1.imshow(
        F * domains_nan, cmap=my_cmap, aspect="equal", origin="lower"
    )
    divider = make_axes_locatable(ax1)
    cax = divider.append_axes("bottom", size="5%", pad=0.3)
    ax1.grid(False)
    ax1.set_title(r"$f$", fontsize=20)
    plt.colorbar(img, cax=cax, orientation="horizontal")

    ax2 = plt.subplot(132)
    img = ax2.imshow(
        (Y[0, :, :, 0] * X[:, :, 1] + X[:, :, 2]) * domains_nan,
        cmap=my_cmap,
        aspect="equal",
        origin="lower",
    )
    divider = make_axes_locatable(ax2)
    cax = divider.append_axes("bottom", size="5%", pad=0.3)
    ax2.grid(False)
    ax2.set_title(r"$\phi w_{pred}$", fontsize=20)
    plt.colorbar(img, cax=cax, orientation="horizontal")

    ax3 = plt.subplot(133)
    img = ax3.imshow(
        (W_ref[:, :, 0] * X[:, :, 1] + X[:, :, 2]) * domains_nan,
        cmap=my_cmap,
        aspect="equal",
        origin="lower",
    )
    divider = make_axes_locatable(ax3)
    cax = divider.append_axes("bottom", size="5%", pad=0.3)
    ax3.grid(False)
    ax3.set_title(r"$\phi w_{ref}$", fontsize=20)
    plt.colorbar(img, cax=cax, orientation="horizontal")

    if save_figs:
        plt.savefig(f"./images_{nb_data}/best_prediction_{L2_error[i]:6f}.png")
    plt.show()

    params = params_val[i]
    print(
        f"(mu0, mu1, sigma, x_0, y_0, lx, ly, theta, alpha, beta) = {params}"
    )
    print(f"{L2_error[i]:6f}")
# Out:
# 119
# [119]
# (mu0, mu1, sigma, x_0, y_0, lx, ly, theta, alpha, beta) = [0.62703224 0.32679117 0.21911799 0.53826443 0.42262047 0.28583816
#  0.21498502 2.37512622 0.32595814 0.31205162]
# 0.000775

# %% [markdown]
# # Erreur relative en fonction des epochs

# %% [markdown]
# ## Jeu de validation

# %%
errors = []
Linf_errors = []

for i in epochs:
    agent.model.load_weights(f"./models_{nb_data}/model_{i}/model_weights")
    X_val, Y_val = agent.data.X_val, agent.data.Y_val
    Y_pred = agent.model.call(X_val)
    domain = X_val[:, :, :, -2]
    boundary = X_val[:, :, :, -1]
    nb_vert = np.shape(boundary)[1]
    domain_prop = tf.reduce_sum(domain, axis=[1, 2]) / nb_vert**2
    boundary_prop = tf.reduce_sum(boundary, axis=[1, 2]) / nb_vert**2

    diff = (
        Y_val * X_val[:, :, :, 1, None]
        + X_val[:, :, :, 2, None]
        - (Y_pred * X_val[:, :, :, 1, None] + X_val[:, :, :, 2, None])
    )

    val = tf.sqrt(
        tf.reduce_mean(
            (diff**2)
            * X_val[:, :, :, -2, None]
            / (domain_prop[:, None, None, None]),
            axis=[1, 2, 3],
        )
        / tf.reduce_mean(
            ((Y_val * X_val[:, :, :, 1, None] + X_val[:, :, :, 2, None]) ** 2)
            * X_val[:, :, :, -2, None]
            / (domain_prop[:, None, None, None]),
            axis=[1, 2, 3],
        )
    )

    errors.append(val)
    Linf_errors.append(
        np.max(
            np.max(np.absolute(diff * X_val[:, :, :, -2, None]), axis=1),
            axis=1,
        )
        / np.max(
            np.max(
                np.absolute(
                    (Y_val * X_val[:, :, :, 1, None] + X_val[:, :, :, 2, None])
                    * X_val[:, :, :, -2, None]
                ),
                axis=1,
            ),
            axis=1,
        )
    )

# %%
j, k = 0, 0
fig, axes = plt.subplots(
    nb_rows,
    size_row,
    figsize=(size_per_fig * size_row, size_per_fig * nb_rows),
)

for i in range(len(indices)):
    if k == size_row:
        k = 0
        j += 1
    sns.histplot(
        data=errors[indices[i]],
        kde=True,
        bins=20,
        color=colors[2],
        edgecolor="k",
        log_scale=True,
        label=str(epochs[indices[i]]),
        stat="proportion",
        legend=True,
        ax=axes[j, k],
    )
    axes[j, k].set_xlabel("$L^2$ relative error")
    axes[j, k].legend()
    axes[j, k].set_xlim(2e-4, 2e-1)
    axes[j, k].set_ylim(0.0, 0.17)
    k += 1

plt.tight_layout()
if save_figs:
    plt.savefig(f"./images_{nb_data}/histograms_validation_L2.png")
plt.show()

# %%
j, k = 0, 0
fig, axes = plt.subplots(
    nb_rows,
    size_row,
    figsize=(size_per_fig * size_row, size_per_fig * nb_rows),
)

for i in range(len(indices)):
    if k == size_row:
        k = 0
        j += 1
    sns.histplot(
        data=Linf_errors[indices[i]],
        kde=True,
        bins=20,
        color=colors[2],
        edgecolor="k",
        log_scale=True,
        label=str(epochs[indices[i]]),
        stat="proportion",
        legend=True,
        ax=axes[j, k],
    )
    axes[j, k].set_xlabel("$L^\infty$ relative error")
    axes[j, k].legend()
    axes[j, k].set_xlim(2e-4, 5e-1)
    axes[j, k].set_ylim(0.0, 0.160)
    k += 1

plt.tight_layout()
if save_figs:
    plt.savefig(f"./images_{nb_data}/histograms_validation_Linf.png")
plt.show()

# %%
plt.figure(figsize=(10, 5))

"""
On crée des dataframe de la forme
|epoch|error|norm|
où type est L2 ou Linf et epoch est un multiple de 250
"""

size_val = len(errors[0])

epoch_repeat = np.array([])
for epoch in epochs:
    tab = np.repeat(str(epoch), size_val)
    epoch_repeat = np.concatenate([epoch_repeat, tab], axis=0)

tab_L2 = np.repeat(["$L^2$"], size_val * len(epochs))

errors_L2_flatten = np.array(errors).flatten()

df_array_L2 = np.stack([epoch_repeat, errors_L2_flatten, tab_L2], axis=0)

tab_Linf = np.repeat(["$L^\infty$"], size_val * len(epochs))
errors_Linf_flatten = np.array(Linf_errors).flatten()
df_array_Linf = np.stack([epoch_repeat, errors_Linf_flatten, tab_Linf], axis=0)

df_array = np.concatenate([df_array_L2, df_array_Linf], axis=1)

name = ["Epochs", "Error", "Norm"]
df_errors = pd.DataFrame(df_array.transpose(), columns=name)
df_errors = df_errors.astype(
    {"Epochs": "int", "Error": "float64", "Norm": "category"}
)

sns.boxplot(
    data=df_errors, x="Epochs", y="Error", hue="Norm", dodge=True
)  # ,palette="ch:s=.25,rot=-.25"
plt.yscale("log")
plt.ylabel("Relative error", fontsize=15)
plt.xlabel("Epochs", fontsize=15)
plt.tight_layout()

if save_figs:
    plt.savefig(f"./images_{nb_data}/boxplots_validation_L2_Linf.png")
plt.show()

# %%
plt.figure(figsize=(10, 5))

errors = np.array(errors[:])
print(np.shape(errors))
dataframe = pd.DataFrame(errors.transpose(), columns=epochs)

sns.boxplot(data=dataframe, palette="ch:s=.25,rot=-.25")
plt.xlabel("Training epochs")
plt.ylabel("$L^2$ relative error")
plt.yscale("log")
plt.grid(True, "both", "y")
plt.tight_layout()
plt.savefig(f"./images_{nb_data}/boxplots_validation_epochs_L2_error.png")
plt.show()
# Out:
# (8, 187)

# %%
epochs_means = list(i * 50 for i in range(1, 41))

print(len(epochs_means))
print(epochs_means)

errors = []
Linf_errors = []

for i in epochs_means:
    agent.model.load_weights(f"./models_{nb_data}/model_{i}/model_weights")
    X_val, Y_val = agent.data.X_val, agent.data.Y_val
    Y_pred = agent.model.call(X_val)
    domain = X_val[:, :, :, -2]
    boundary = X_val[:, :, :, -1]
    nb_vert = np.shape(boundary)[1]
    domain_prop = tf.reduce_sum(domain, axis=[1, 2]) / nb_vert**2
    boundary_prop = tf.reduce_sum(boundary, axis=[1, 2]) / nb_vert**2

    diff = (
        Y_val * X_val[:, :, :, 1, None]
        + X_val[:, :, :, 2, None]
        - (Y_pred * X_val[:, :, :, 1, None] + X_val[:, :, :, 2, None])
    )

    val = tf.sqrt(
        tf.reduce_mean(
            (diff**2)
            * X_val[:, :, :, -2, None]
            / (domain_prop[:, None, None, None]),
            axis=[1, 2, 3],
        )
        / tf.reduce_mean(
            ((Y_val * X_val[:, :, :, 1, None] + X_val[:, :, :, 2, None]) ** 2)
            * X_val[:, :, :, -2, None]
            / (domain_prop[:, None, None, None]),
            axis=[1, 2, 3],
        )
    )

    errors.append(val)
    Linf_errors.append(
        np.max(
            np.max(np.absolute(diff * X_val[:, :, :, -2, None]), axis=1),
            axis=1,
        )
        / np.max(
            np.max(
                np.absolute(
                    (Y_val * X_val[:, :, :, 1, None] + X_val[:, :, :, 2, None])
                    * X_val[:, :, :, -2, None]
                ),
                axis=1,
            ),
            axis=1,
        )
    )
# Out:
# 40
# [50, 100, 150, 200, 250, 300, 350, 400, 450, 500, 550, 600, 650, 700, 750, 800, 850, 900, 950, 1000, 1050, 1100, 1150, 1200, 1250, 1300, 1350, 1400, 1450, 1500, 1550, 1600, 1650, 1700, 1750, 1800, 1850, 1900, 1950, 2000]

# %%
means = np.mean(errors, axis=1)
standard_deviation = np.std(errors, axis=1)
maxs = np.max(errors, axis=1)
mins = np.min(errors, axis=1)

plt.figure(figsize=(8, 3))
plt.subplot(1, 2, 1)
plt.semilogy(epochs_means, means, "-+", label="Mean")
plt.xlabel("Epochs")
plt.ylabel("$L^2$ relative error")
plt.semilogy(
    epochs_means, standard_deviation, "-+", label="Standard deviation"
)
plt.xlabel("Epochs")
plt.ylabel("$L^2$ relative error")
plt.grid(True, "both", "both")
plt.legend()

plt.subplot(1, 2, 2)
plt.semilogy(epochs_means, maxs, "-+", label="Maximum")
plt.semilogy(epochs_means, mins, "-+", label="Minimum")
plt.grid(True, "both", "both")
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("$L^2$ relative error")
plt.tight_layout()

if save_figs:
    plt.savefig(f"./images_{nb_data}/min_mean_max_L2_error_epochs.png")
plt.show()

# %% [markdown]
# # Erreur sur un nouveau jeu de données

# %%
from generate_data import PhiFemSolver

# %%
u_exs, V_exs, dx_exs = [], [], []
L2_error_phi_fem, L2_error_std_fem = [], []
Temps_phi, Temps_std = [], []

F, Phi, G, params = create_FG_numpy(300, 64)
solver = PhiFemSolver(nb_cell=64 - 1, params=params)
W_phi_fem = solver.solve_several()
print(f"{np.shape(W_phi_fem)=}")

errors_fno, times_fno = [], []

for j in epochs:
    print(f"Epoch : {j}")
    agent.model.load_weights(f"./models_{nb_data}/model_{j}/model_weights")
    L2_error_fno = []
    Temps_fno = []
    X = generate_manual_new_data_numpy(Phi, F / data.max_norm_F, G)
    Y_pred = agent.model.call(X)

    domain = X[:, :, :, -2]
    boundary = X[:, :, :, -1]
    nb_vert = np.shape(boundary)[1]
    domain_prop = tf.reduce_sum(domain, axis=[1, 2]) / nb_vert**2
    boundary_prop = tf.reduce_sum(boundary, axis=[1, 2]) / nb_vert**2
    diff = (
        W_phi_fem[:, :, :] * X[:, :, :, 1]
        + G
        - (Y_pred[:, :, :, 0] * X[:, :, :, 1] + G)
    )

    L2_error_fno = tf.sqrt(
        tf.reduce_mean(
            (diff**2) * X[:, :, :, -2] / (domain_prop[:, None, None]),
            axis=[1, 2],
        )
        / tf.reduce_mean(
            ((W_phi_fem * X[:, :, :, 1] + G) ** 2)
            * X[:, :, :, -2]
            / (domain_prop[:, None, None]),
            axis=[1, 2],
        )
    )

    errors_fno.append(L2_error_fno)
# Out:
# 0/300:num of cell in the ghost penalty: 190
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 2883 nodes for 1442 points.
# 1/300:num of cell in the ghost penalty: 216
# Solving linear variational problem.
# 2/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3661 nodes for 1831 points.
# num of cell in the ghost penalty: 200
# Solving linear variational problem.
# 3/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3001 nodes for 1501 points.
# num of cell in the ghost penalty: 260
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 4417 nodes for 2209 points.
# 4/300:num of cell in the ghost penalty: 252
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 4541 nodes for 2271 points.
# 5/300:num of cell in the ghost penalty: 202
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3271 nodes for 1636 points.
# 6/300:num of cell in the ghost penalty: 222
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 7/300:Computed bounding box tree with 3839 nodes for 1920 points.
# num of cell in the ghost penalty: 202
# Solving linear variational problem.
# 8/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 2943 nodes for 1472 points.
# num of cell in the ghost penalty: 228
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 9/300:Computed bounding box tree with 3825 nodes for 1913 points.
# num of cell in the ghost penalty: 210
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3351 nodes for 1676 points.
# 10/300:num of cell in the ghost penalty: 196
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 11/300:Computed bounding box tree with 2697 nodes for 1349 points.
# num of cell in the ghost penalty: 342
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 12/300:Computed bounding box tree with 8327 nodes for 4164 points.
# num of cell in the ghost penalty: 216
# Solving linear variational problem.
# 13/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3357 nodes for 1679 points.
# num of cell in the ghost penalty: 206
# Solving linear variational problem.
# 14/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 2995 nodes for 1498 points.
# num of cell in the ghost penalty: 190
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 15/300:Computed bounding box tree with 2587 nodes for 1294 points.
# num of cell in the ghost penalty: 270
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 16/300:Computed bounding box tree with 5427 nodes for 2714 points.
# num of cell in the ghost penalty: 300
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 17/300:Computed bounding box tree with 6625 nodes for 3313 points.
# num of cell in the ghost penalty: 258
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 4219 nodes for 2110 points.
# 18/300:num of cell in the ghost penalty: 250
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 19/300:Computed bounding box tree with 4347 nodes for 2174 points.
# num of cell in the ghost penalty: 318
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 20/300:Computed bounding box tree with 7031 nodes for 3516 points.
# num of cell in the ghost penalty: 212
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 21/300:Computed bounding box tree with 3377 nodes for 1689 points.
# num of cell in the ghost penalty: 298
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 4599 nodes for 2300 points.
# 22/300:num of cell in the ghost penalty: 202
# Solving linear variational problem.
# 23/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3063 nodes for 1532 points.
# num of cell in the ghost penalty: 294
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 24/300:Computed bounding box tree with 6135 nodes for 3068 points.
# num of cell in the ghost penalty: 246
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 4327 nodes for 2164 points.
# 25/300:num of cell in the ghost penalty: 214
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3035 nodes for 1518 points.
# 26/300:num of cell in the ghost penalty: 232
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 27/300:Computed bounding box tree with 4133 nodes for 2067 points.
# num of cell in the ghost penalty: 236
# Solving linear variational problem.
# 28/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 4017 nodes for 2009 points.
# num of cell in the ghost penalty: 258
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 4951 nodes for 2476 points.
# 29/300:num of cell in the ghost penalty: 230
# Solving linear variational problem.
# 30/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 4071 nodes for 2036 points.
# num of cell in the ghost penalty: 236
# Solving linear variational problem.
# 31/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 4193 nodes for 2097 points.
# num of cell in the ghost penalty: 246
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 32/300:Computed bounding box tree with 4663 nodes for 2332 points.
# num of cell in the ghost penalty: 248
# Solving linear variational problem.
# 33/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 4325 nodes for 2163 points.
# num of cell in the ghost penalty: 206
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 34/300:Computed bounding box tree with 3111 nodes for 1556 points.
# num of cell in the ghost penalty: 226
# Solving linear variational problem.
# 35/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3647 nodes for 1824 points.
# num of cell in the ghost penalty: 310
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 36/300:Computed bounding box tree with 5871 nodes for 2936 points.
# num of cell in the ghost penalty: 206
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 2935 nodes for 1468 points.
# 37/300:num of cell in the ghost penalty: 208
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 38/300:Computed bounding box tree with 2873 nodes for 1437 points.
# num of cell in the ghost penalty: 242
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 39/300:Computed bounding box tree with 4551 nodes for 2276 points.
# num of cell in the ghost penalty: 204
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 40/300:Computed bounding box tree with 3117 nodes for 1559 points.
# num of cell in the ghost penalty: 182
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 41/300:Computed bounding box tree with 2491 nodes for 1246 points.
# num of cell in the ghost penalty: 274
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 4915 nodes for 2458 points.
# 42/300:num of cell in the ghost penalty: 222
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3655 nodes for 1828 points.
# 43/300:num of cell in the ghost penalty: 266
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 4455 nodes for 2228 points.
# 44/300:num of cell in the ghost penalty: 232
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 45/300:Computed bounding box tree with 3901 nodes for 1951 points.
# num of cell in the ghost penalty: 192
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 2665 nodes for 1333 points.
# 46/300:num of cell in the ghost penalty: 208
# Solving linear variational problem.
# 47/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3037 nodes for 1519 points.
# num of cell in the ghost penalty: 316
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 48/300:Computed bounding box tree with 5869 nodes for 2935 points.
# num of cell in the ghost penalty: 304
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 49/300:Computed bounding box tree with 6461 nodes for 3231 points.
# num of cell in the ghost penalty: 240
# Solving linear variational problem.
# 50/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 4193 nodes for 2097 points.
# num of cell in the ghost penalty: 206
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3203 nodes for 1602 points.
# 51/300:num of cell in the ghost penalty: 224
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3825 nodes for 1913 points.
# 52/300:num of cell in the ghost penalty: 220
# Solving linear variational problem.
# 53/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3649 nodes for 1825 points.
# num of cell in the ghost penalty: 304
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 54/300:Computed bounding box tree with 6369 nodes for 3185 points.
# num of cell in the ghost penalty: 194
# Solving linear variational problem.
# 55/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 2835 nodes for 1418 points.
# num of cell in the ghost penalty: 274
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 56/300:Computed bounding box tree with 5051 nodes for 2526 points.
# num of cell in the ghost penalty: 210
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 57/300:Computed bounding box tree with 3159 nodes for 1580 points.
# num of cell in the ghost penalty: 276
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 58/300:Computed bounding box tree with 5497 nodes for 2749 points.
# num of cell in the ghost penalty: 192
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 2681 nodes for 1341 points.
# 59/300:num of cell in the ghost penalty: 242
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3731 nodes for 1866 points.
# 60/300:num of cell in the ghost penalty: 266
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 61/300:Computed bounding box tree with 4663 nodes for 2332 points.
# num of cell in the ghost penalty: 230
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 62/300:Computed bounding box tree with 3247 nodes for 1624 points.
# num of cell in the ghost penalty: 290
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 63/300:Computed bounding box tree with 4299 nodes for 2150 points.
# num of cell in the ghost penalty: 202
# Solving linear variational problem.
# 64/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 2847 nodes for 1424 points.
# num of cell in the ghost penalty: 210
# Solving linear variational problem.
# 65/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 2859 nodes for 1430 points.
# num of cell in the ghost penalty: 268
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 66/300:Computed bounding box tree with 4637 nodes for 2319 points.
# num of cell in the ghost penalty: 270
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 67/300:Computed bounding box tree with 5567 nodes for 2784 points.
# num of cell in the ghost penalty: 296
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 68/300:Computed bounding box tree with 6741 nodes for 3371 points.
# num of cell in the ghost penalty: 234
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 69/300:Computed bounding box tree with 3859 nodes for 1930 points.
# num of cell in the ghost penalty: 224
# Solving linear variational problem.
# 70/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3965 nodes for 1983 points.
# num of cell in the ghost penalty: 190
# Solving linear variational problem.
# 71/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 2627 nodes for 1314 points.
# num of cell in the ghost penalty: 214
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3271 nodes for 1636 points.
# 72/300:num of cell in the ghost penalty: 200
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 73/300:Computed bounding box tree with 2929 nodes for 1465 points.
# num of cell in the ghost penalty: 294
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 74/300:Computed bounding box tree with 6423 nodes for 3212 points.
# num of cell in the ghost penalty: 282
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 75/300:Computed bounding box tree with 5751 nodes for 2876 points.
# num of cell in the ghost penalty: 240
# Solving linear variational problem.
# 76/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3981 nodes for 1991 points.
# num of cell in the ghost penalty: 286
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 77/300:Computed bounding box tree with 5539 nodes for 2770 points.
# num of cell in the ghost penalty: 304
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 5401 nodes for 2701 points.
# 78/300:num of cell in the ghost penalty: 254
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 79/300:Computed bounding box tree with 4779 nodes for 2390 points.
# num of cell in the ghost penalty: 262
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 80/300:Computed bounding box tree with 4915 nodes for 2458 points.
# num of cell in the ghost penalty: 288
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 81/300:Computed bounding box tree with 5493 nodes for 2747 points.
# num of cell in the ghost penalty: 222
# Solving linear variational problem.
# 82/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3163 nodes for 1582 points.
# num of cell in the ghost penalty: 190
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 83/300:Computed bounding box tree with 2611 nodes for 1306 points.
# num of cell in the ghost penalty: 306
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 84/300:Computed bounding box tree with 6579 nodes for 3290 points.
# num of cell in the ghost penalty: 298
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 85/300:Computed bounding box tree with 6211 nodes for 3106 points.
# num of cell in the ghost penalty: 210
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 86/300:Computed bounding box tree with 3039 nodes for 1520 points.
# num of cell in the ghost penalty: 228
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 87/300:Computed bounding box tree with 3445 nodes for 1723 points.
# num of cell in the ghost penalty: 266
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 88/300:Computed bounding box tree with 5119 nodes for 2560 points.
# num of cell in the ghost penalty: 262
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 89/300:Computed bounding box tree with 4979 nodes for 2490 points.
# num of cell in the ghost penalty: 224
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 90/300:Computed bounding box tree with 3433 nodes for 1717 points.
# num of cell in the ghost penalty: 294
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 91/300:Computed bounding box tree with 5947 nodes for 2974 points.
# num of cell in the ghost penalty: 210
# Solving linear variational problem.
# 92/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 2911 nodes for 1456 points.
# num of cell in the ghost penalty: 290
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 93/300:Computed bounding box tree with 5099 nodes for 2550 points.
# num of cell in the ghost penalty: 302
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 94/300:Computed bounding box tree with 4983 nodes for 2492 points.
# num of cell in the ghost penalty: 238
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 95/300:Computed bounding box tree with 4379 nodes for 2190 points.
# num of cell in the ghost penalty: 186
# Solving linear variational problem.
# 96/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 2555 nodes for 1278 points.
# num of cell in the ghost penalty: 250
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 4431 nodes for 2216 points.
# 97/300:num of cell in the ghost penalty: 280
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 98/300:Computed bounding box tree with 5505 nodes for 2753 points.
# num of cell in the ghost penalty: 214
# Solving linear variational problem.
# 99/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3403 nodes for 1702 points.
# num of cell in the ghost penalty: 248
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 100/300:Computed bounding box tree with 3681 nodes for 1841 points.
# num of cell in the ghost penalty: 222
# Solving linear variational problem.
# 101/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3859 nodes for 1930 points.
# num of cell in the ghost penalty: 208
# Solving linear variational problem.
# 102/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 2953 nodes for 1477 points.
# num of cell in the ghost penalty: 252
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 103/300:Computed bounding box tree with 4457 nodes for 2229 points.
# num of cell in the ghost penalty: 218
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3587 nodes for 1794 points.
# 104/300:num of cell in the ghost penalty: 246
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 105/300:Computed bounding box tree with 4447 nodes for 2224 points.
# num of cell in the ghost penalty: 210
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 106/300:Computed bounding box tree with 3331 nodes for 1666 points.
# num of cell in the ghost penalty: 284
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 107/300:Computed bounding box tree with 5197 nodes for 2599 points.
# num of cell in the ghost penalty: 210
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3259 nodes for 1630 points.
# 108/300:num of cell in the ghost penalty: 234
# Solving linear variational problem.
# 109/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 4055 nodes for 2028 points.
# num of cell in the ghost penalty: 198
# Solving linear variational problem.
# 110/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3051 nodes for 1526 points.
# num of cell in the ghost penalty: 280
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 111/300:Computed bounding box tree with 5421 nodes for 2711 points.
# num of cell in the ghost penalty: 238
# Solving linear variational problem.
# 112/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3615 nodes for 1808 points.
# num of cell in the ghost penalty: 190
# Solving linear variational problem.
# 113/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 2651 nodes for 1326 points.
# num of cell in the ghost penalty: 246
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 114/300:Computed bounding box tree with 4615 nodes for 2308 points.
# num of cell in the ghost penalty: 210
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 115/300:Computed bounding box tree with 3191 nodes for 1596 points.
# num of cell in the ghost penalty: 254
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 116/300:Computed bounding box tree with 4567 nodes for 2284 points.
# num of cell in the ghost penalty: 262
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 4655 nodes for 2328 points.
# 117/300:num of cell in the ghost penalty: 250
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 4191 nodes for 2096 points.
# 118/300:num of cell in the ghost penalty: 218
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3295 nodes for 1648 points.
# 119/300:num of cell in the ghost penalty: 210
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 120/300:Computed bounding box tree with 3103 nodes for 1552 points.
# num of cell in the ghost penalty: 304
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 121/300:Computed bounding box tree with 4497 nodes for 2249 points.
# num of cell in the ghost penalty: 256
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 122/300:Computed bounding box tree with 4989 nodes for 2495 points.
# num of cell in the ghost penalty: 264
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 123/300:Computed bounding box tree with 5285 nodes for 2643 points.
# num of cell in the ghost penalty: 238
# Solving linear variational problem.
# 124/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3823 nodes for 1912 points.
# num of cell in the ghost penalty: 294
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 125/300:Computed bounding box tree with 4887 nodes for 2444 points.
# num of cell in the ghost penalty: 250
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 126/300:Computed bounding box tree with 4375 nodes for 2188 points.
# num of cell in the ghost penalty: 280
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 127/300:Computed bounding box tree with 4805 nodes for 2403 points.
# num of cell in the ghost penalty: 190
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 128/300:Computed bounding box tree with 2663 nodes for 1332 points.
# num of cell in the ghost penalty: 202
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 129/300:Computed bounding box tree with 2935 nodes for 1468 points.
# num of cell in the ghost penalty: 256
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 130/300:Computed bounding box tree with 4109 nodes for 2055 points.
# num of cell in the ghost penalty: 202
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3207 nodes for 1604 points.
# 131/300:num of cell in the ghost penalty: 242
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 132/300:Computed bounding box tree with 4323 nodes for 2162 points.
# num of cell in the ghost penalty: 230
# Solving linear variational problem.
# 133/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3663 nodes for 1832 points.
# num of cell in the ghost penalty: 234
# Solving linear variational problem.
# 134/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3871 nodes for 1936 points.
# num of cell in the ghost penalty: 286
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 135/300:Computed bounding box tree with 5231 nodes for 2616 points.
# num of cell in the ghost penalty: 306
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 136/300:Computed bounding box tree with 6583 nodes for 3292 points.
# num of cell in the ghost penalty: 250
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 137/300:Computed bounding box tree with 4519 nodes for 2260 points.
# num of cell in the ghost penalty: 338
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 138/300:Computed bounding box tree with 7875 nodes for 3938 points.
# num of cell in the ghost penalty: 258
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 139/300:Computed bounding box tree with 4887 nodes for 2444 points.
# num of cell in the ghost penalty: 226
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 140/300:Computed bounding box tree with 3575 nodes for 1788 points.
# num of cell in the ghost penalty: 186
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 2583 nodes for 1292 points.
# 141/300:num of cell in the ghost penalty: 206
# Solving linear variational problem.
# 142/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 2975 nodes for 1488 points.
# num of cell in the ghost penalty: 194
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 143/300:Computed bounding box tree with 2703 nodes for 1352 points.
# num of cell in the ghost penalty: 226
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 144/300:Computed bounding box tree with 3531 nodes for 1766 points.
# num of cell in the ghost penalty: 346
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 145/300:Computed bounding box tree with 7931 nodes for 3966 points.
# num of cell in the ghost penalty: 242
# Solving linear variational problem.
# 146/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3751 nodes for 1876 points.
# num of cell in the ghost penalty: 302
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 147/300:Computed bounding box tree with 6547 nodes for 3274 points.
# num of cell in the ghost penalty: 216
# Solving linear variational problem.
# 148/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3053 nodes for 1527 points.
# num of cell in the ghost penalty: 202
# Solving linear variational problem.
# 149/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 2799 nodes for 1400 points.
# num of cell in the ghost penalty: 290
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 150/300:Computed bounding box tree with 5927 nodes for 2964 points.
# num of cell in the ghost penalty: 204
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 151/300:Computed bounding box tree with 3137 nodes for 1569 points.
# num of cell in the ghost penalty: 234
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 4243 nodes for 2122 points.
# 152/300:num of cell in the ghost penalty: 240
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 153/300:Computed bounding box tree with 3545 nodes for 1773 points.
# num of cell in the ghost penalty: 306
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 154/300:Computed bounding box tree with 6295 nodes for 3148 points.
# num of cell in the ghost penalty: 280
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 155/300:Computed bounding box tree with 5665 nodes for 2833 points.
# num of cell in the ghost penalty: 292
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 156/300:Computed bounding box tree with 5153 nodes for 2577 points.
# num of cell in the ghost penalty: 280
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 157/300:Computed bounding box tree with 4833 nodes for 2417 points.
# num of cell in the ghost penalty: 272
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 158/300:Computed bounding box tree with 5333 nodes for 2667 points.
# num of cell in the ghost penalty: 218
# Solving linear variational problem.
# 159/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3435 nodes for 1718 points.
# num of cell in the ghost penalty: 266
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 160/300:Computed bounding box tree with 5143 nodes for 2572 points.
# num of cell in the ghost penalty: 284
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 161/300:Computed bounding box tree with 4949 nodes for 2475 points.
# num of cell in the ghost penalty: 242
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 162/300:Computed bounding box tree with 4179 nodes for 2090 points.
# num of cell in the ghost penalty: 254
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 163/300:Computed bounding box tree with 4587 nodes for 2294 points.
# num of cell in the ghost penalty: 222
# Solving linear variational problem.
# 164/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3551 nodes for 1776 points.
# num of cell in the ghost penalty: 208
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 165/300:Computed bounding box tree with 3457 nodes for 1729 points.
# num of cell in the ghost penalty: 186
# Solving linear variational problem.
# 166/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 2559 nodes for 1280 points.
# num of cell in the ghost penalty: 218
# Solving linear variational problem.
# 167/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3703 nodes for 1852 points.
# num of cell in the ghost penalty: 350
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 168/300:Computed bounding box tree with 8623 nodes for 4312 points.
# num of cell in the ghost penalty: 226
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 169/300:Computed bounding box tree with 3431 nodes for 1716 points.
# num of cell in the ghost penalty: 208
# Solving linear variational problem.
# 170/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3025 nodes for 1513 points.
# num of cell in the ghost penalty: 218
# Solving linear variational problem.
# 171/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3499 nodes for 1750 points.
# num of cell in the ghost penalty: 248
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3569 nodes for 1785 points.
# 172/300:num of cell in the ghost penalty: 250
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 4503 nodes for 2252 points.
# 173/300:num of cell in the ghost penalty: 288
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 5065 nodes for 2533 points.
# 174/300:num of cell in the ghost penalty: 254
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 175/300:Computed bounding box tree with 4807 nodes for 2404 points.
# num of cell in the ghost penalty: 244
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 176/300:Computed bounding box tree with 4133 nodes for 2067 points.
# num of cell in the ghost penalty: 254
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 177/300:Computed bounding box tree with 4823 nodes for 2412 points.
# num of cell in the ghost penalty: 220
# Solving linear variational problem.
# 178/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3413 nodes for 1707 points.
# num of cell in the ghost penalty: 250
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 179/300:Computed bounding box tree with 3963 nodes for 1982 points.
# num of cell in the ghost penalty: 262
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 180/300:Computed bounding box tree with 4839 nodes for 2420 points.
# num of cell in the ghost penalty: 238
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 181/300:Computed bounding box tree with 4071 nodes for 2036 points.
# num of cell in the ghost penalty: 256
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 182/300:Computed bounding box tree with 5057 nodes for 2529 points.
# num of cell in the ghost penalty: 254
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 183/300:Computed bounding box tree with 4679 nodes for 2340 points.
# num of cell in the ghost penalty: 228
# Solving linear variational problem.
# 184/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3469 nodes for 1735 points.
# num of cell in the ghost penalty: 318
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 185/300:Computed bounding box tree with 7279 nodes for 3640 points.
# num of cell in the ghost penalty: 176
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 186/300:Computed bounding box tree with 2301 nodes for 1151 points.
# num of cell in the ghost penalty: 196
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 187/300:Computed bounding box tree with 2713 nodes for 1357 points.
# num of cell in the ghost penalty: 234
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 188/300:Computed bounding box tree with 3771 nodes for 1886 points.
# num of cell in the ghost penalty: 222
# Solving linear variational problem.
# 189/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3367 nodes for 1684 points.
# num of cell in the ghost penalty: 314
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 190/300:Computed bounding box tree with 6679 nodes for 3340 points.
# num of cell in the ghost penalty: 182
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 191/300:Computed bounding box tree with 2467 nodes for 1234 points.
# num of cell in the ghost penalty: 336
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 192/300:Computed bounding box tree with 7365 nodes for 3683 points.
# num of cell in the ghost penalty: 292
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 193/300:Computed bounding box tree with 6329 nodes for 3165 points.
# num of cell in the ghost penalty: 284
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 194/300:Computed bounding box tree with 5573 nodes for 2787 points.
# num of cell in the ghost penalty: 242
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 195/300:Computed bounding box tree with 4651 nodes for 2326 points.
# num of cell in the ghost penalty: 198
# Solving linear variational problem.
# 196/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3075 nodes for 1538 points.
# num of cell in the ghost penalty: 322
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 7119 nodes for 3560 points.
# 197/300:num of cell in the ghost penalty: 246
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 198/300:Computed bounding box tree with 4155 nodes for 2078 points.
# num of cell in the ghost penalty: 202
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 199/300:Computed bounding box tree with 2923 nodes for 1462 points.
# num of cell in the ghost penalty: 232
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 200/300:Computed bounding box tree with 3505 nodes for 1753 points.
# num of cell in the ghost penalty: 216
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 201/300:Computed bounding box tree with 3509 nodes for 1755 points.
# num of cell in the ghost penalty: 206
# Solving linear variational problem.
# 202/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3271 nodes for 1636 points.
# num of cell in the ghost penalty: 324
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 6813 nodes for 3407 points.
# 203/300:num of cell in the ghost penalty: 282
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 204/300:Computed bounding box tree with 4359 nodes for 2180 points.
# num of cell in the ghost penalty: 200
# Solving linear variational problem.
# 205/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3057 nodes for 1529 points.
# num of cell in the ghost penalty: 252
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 206/300:Computed bounding box tree with 4941 nodes for 2471 points.
# num of cell in the ghost penalty: 252
# Solving linear variational problem.
# 207/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 4281 nodes for 2141 points.
# num of cell in the ghost penalty: 272
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 208/300:Computed bounding box tree with 5201 nodes for 2601 points.
# num of cell in the ghost penalty: 306
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 209/300:Computed bounding box tree with 4583 nodes for 2292 points.
# num of cell in the ghost penalty: 174
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 210/300:Computed bounding box tree with 2235 nodes for 1118 points.
# num of cell in the ghost penalty: 238
# Solving linear variational problem.
# 211/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 4035 nodes for 2018 points.
# num of cell in the ghost penalty: 230
# Solving linear variational problem.
# 212/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3859 nodes for 1930 points.
# num of cell in the ghost penalty: 302
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 213/300:Computed bounding box tree with 6679 nodes for 3340 points.
# num of cell in the ghost penalty: 214
# Solving linear variational problem.
# 214/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3039 nodes for 1520 points.
# num of cell in the ghost penalty: 218
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 215/300:Computed bounding box tree with 3235 nodes for 1618 points.
# num of cell in the ghost penalty: 234
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 216/300:Computed bounding box tree with 4119 nodes for 2060 points.
# num of cell in the ghost penalty: 206
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 217/300:Computed bounding box tree with 3259 nodes for 1630 points.
# num of cell in the ghost penalty: 188
# Solving linear variational problem.
# 218/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 2525 nodes for 1263 points.
# num of cell in the ghost penalty: 206
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 219/300:Computed bounding box tree with 3115 nodes for 1558 points.
# num of cell in the ghost penalty: 204
# Solving linear variational problem.
# 220/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3285 nodes for 1643 points.
# num of cell in the ghost penalty: 202
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 2999 nodes for 1500 points.
# 221/300:num of cell in the ghost penalty: 232
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3233 nodes for 1617 points.
# 222/300:num of cell in the ghost penalty: 234
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 223/300:Computed bounding box tree with 4223 nodes for 2112 points.
# num of cell in the ghost penalty: 246
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 224/300:Computed bounding box tree with 4407 nodes for 2204 points.
# num of cell in the ghost penalty: 246
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 225/300:Computed bounding box tree with 4047 nodes for 2024 points.
# num of cell in the ghost penalty: 218
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3275 nodes for 1638 points.
# 226/300:num of cell in the ghost penalty: 202
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 227/300:Computed bounding box tree with 2995 nodes for 1498 points.
# num of cell in the ghost penalty: 232
# Solving linear variational problem.
# 228/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3953 nodes for 1977 points.
# num of cell in the ghost penalty: 212
# Solving linear variational problem.
# 229/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3101 nodes for 1551 points.
# num of cell in the ghost penalty: 198
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 2843 nodes for 1422 points.
# 230/300:num of cell in the ghost penalty: 202
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 231/300:Computed bounding box tree with 3019 nodes for 1510 points.
# num of cell in the ghost penalty: 198
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 232/300:Computed bounding box tree with 2911 nodes for 1456 points.
# num of cell in the ghost penalty: 208
# Solving linear variational problem.
# 233/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3373 nodes for 1687 points.
# num of cell in the ghost penalty: 226
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 234/300:Computed bounding box tree with 3271 nodes for 1636 points.
# num of cell in the ghost penalty: 314
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 5803 nodes for 2902 points.
# 235/300:num of cell in the ghost penalty: 198
# Solving linear variational problem.
# 236/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 2883 nodes for 1442 points.
# num of cell in the ghost penalty: 184
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 237/300:Computed bounding box tree with 2489 nodes for 1245 points.
# num of cell in the ghost penalty: 262
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 238/300:Computed bounding box tree with 4503 nodes for 2252 points.
# num of cell in the ghost penalty: 228
# Solving linear variational problem.
# 239/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3653 nodes for 1827 points.
# num of cell in the ghost penalty: 224
# Solving linear variational problem.
# 240/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3557 nodes for 1779 points.
# num of cell in the ghost penalty: 292
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 241/300:Computed bounding box tree with 6009 nodes for 3005 points.
# num of cell in the ghost penalty: 228
# Solving linear variational problem.
# 242/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3777 nodes for 1889 points.
# num of cell in the ghost penalty: 206
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 243/300:Computed bounding box tree with 3023 nodes for 1512 points.
# num of cell in the ghost penalty: 178
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 244/300:Computed bounding box tree with 2355 nodes for 1178 points.
# num of cell in the ghost penalty: 250
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 4471 nodes for 2236 points.
# 245/300:num of cell in the ghost penalty: 206
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3287 nodes for 1644 points.
# 246/300:num of cell in the ghost penalty: 236
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 247/300:Computed bounding box tree with 4189 nodes for 2095 points.
# num of cell in the ghost penalty: 260
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 248/300:Computed bounding box tree with 4653 nodes for 2327 points.
# num of cell in the ghost penalty: 198
# Solving linear variational problem.
# 249/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 2831 nodes for 1416 points.
# num of cell in the ghost penalty: 188
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 2497 nodes for 1249 points.
# 250/300:num of cell in the ghost penalty: 242
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 251/300:Computed bounding box tree with 4103 nodes for 2052 points.
# num of cell in the ghost penalty: 214
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 252/300:Computed bounding box tree with 3087 nodes for 1544 points.
# num of cell in the ghost penalty: 248
# Solving linear variational problem.
# 253/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3789 nodes for 1895 points.
# num of cell in the ghost penalty: 256
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 254/300:Computed bounding box tree with 4697 nodes for 2349 points.
# num of cell in the ghost penalty: 214
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 255/300:Computed bounding box tree with 3127 nodes for 1564 points.
# num of cell in the ghost penalty: 250
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 4615 nodes for 2308 points.
# 256/300:num of cell in the ghost penalty: 244
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 257/300:Computed bounding box tree with 4025 nodes for 2013 points.
# num of cell in the ghost penalty: 206
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 258/300:Computed bounding box tree with 3075 nodes for 1538 points.
# num of cell in the ghost penalty: 274
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 5615 nodes for 2808 points.
# 259/300:num of cell in the ghost penalty: 256
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 260/300:Computed bounding box tree with 4729 nodes for 2365 points.
# num of cell in the ghost penalty: 274
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 4263 nodes for 2132 points.
# 261/300:num of cell in the ghost penalty: 262
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 4415 nodes for 2208 points.
# 262/300:num of cell in the ghost penalty: 248
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 263/300:Computed bounding box tree with 4481 nodes for 2241 points.
# num of cell in the ghost penalty: 208
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3345 nodes for 1673 points.
# 264/300:num of cell in the ghost penalty: 258
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 4667 nodes for 2334 points.
# 265/300:num of cell in the ghost penalty: 260
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 266/300:Computed bounding box tree with 4793 nodes for 2397 points.
# num of cell in the ghost penalty: 274
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 267/300:Computed bounding box tree with 4799 nodes for 2400 points.
# num of cell in the ghost penalty: 180
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 268/300:Computed bounding box tree with 2433 nodes for 1217 points.
# num of cell in the ghost penalty: 208
# Solving linear variational problem.
# 269/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3309 nodes for 1655 points.
# num of cell in the ghost penalty: 276
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 270/300:Computed bounding box tree with 5577 nodes for 2789 points.
# num of cell in the ghost penalty: 244
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 271/300:Computed bounding box tree with 4365 nodes for 2183 points.
# num of cell in the ghost penalty: 198
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 272/300:Computed bounding box tree with 2751 nodes for 1376 points.
# num of cell in the ghost penalty: 210
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 273/300:Computed bounding box tree with 3027 nodes for 1514 points.
# num of cell in the ghost penalty: 244
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3901 nodes for 1951 points.
# 274/300:num of cell in the ghost penalty: 286
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 275/300:Computed bounding box tree with 6311 nodes for 3156 points.
# num of cell in the ghost penalty: 224
# Solving linear variational problem.
# 276/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3325 nodes for 1663 points.
# num of cell in the ghost penalty: 276
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 277/300:Computed bounding box tree with 5037 nodes for 2519 points.
# num of cell in the ghost penalty: 232
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 278/300:Computed bounding box tree with 3441 nodes for 1721 points.
# num of cell in the ghost penalty: 212
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 279/300:Computed bounding box tree with 3453 nodes for 1727 points.
# num of cell in the ghost penalty: 238
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 280/300:Computed bounding box tree with 3595 nodes for 1798 points.
# num of cell in the ghost penalty: 296
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 281/300:Computed bounding box tree with 6041 nodes for 3021 points.
# num of cell in the ghost penalty: 208
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 282/300:Computed bounding box tree with 3321 nodes for 1661 points.
# num of cell in the ghost penalty: 276
# Solving linear variational problem.
# 283/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 4001 nodes for 2001 points.
# num of cell in the ghost penalty: 174
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 284/300:Computed bounding box tree with 2195 nodes for 1098 points.
# num of cell in the ghost penalty: 212
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 285/300:Computed bounding box tree with 2929 nodes for 1465 points.
# num of cell in the ghost penalty: 262
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 286/300:Computed bounding box tree with 4811 nodes for 2406 points.
# num of cell in the ghost penalty: 176
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 287/300:Computed bounding box tree with 2277 nodes for 1139 points.
# num of cell in the ghost penalty: 270
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 288/300:Computed bounding box tree with 5263 nodes for 2632 points.
# num of cell in the ghost penalty: 212
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3405 nodes for 1703 points.
# 289/300:num of cell in the ghost penalty: 218
# Solving linear variational problem.
# 290/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3667 nodes for 1834 points.
# num of cell in the ghost penalty: 210
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 291/300:Computed bounding box tree with 3267 nodes for 1634 points.
# num of cell in the ghost penalty: 230
# Solving linear variational problem.
# 292/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3795 nodes for 1898 points.
# num of cell in the ghost penalty: 242
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 293/300:Computed bounding box tree with 3795 nodes for 1898 points.
# num of cell in the ghost penalty: 250
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 294/300:Computed bounding box tree with 4815 nodes for 2408 points.
# num of cell in the ghost penalty: 216
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 295/300:Computed bounding box tree with 3257 nodes for 1629 points.
# num of cell in the ghost penalty: 204
# Solving linear variational problem.
# 296/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 2933 nodes for 1467 points.
# num of cell in the ghost penalty: 234
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 297/300:Computed bounding box tree with 3767 nodes for 1884 points.
# num of cell in the ghost penalty: 300
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 5721 nodes for 2861 points.
# 298/300:num of cell in the ghost penalty: 258
# Solving linear variational problem.
# 299/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 4435 nodes for 2218 points.
# num of cell in the ghost penalty: 216
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3001 nodes for 1501 points.
# np.shape(W_phi_fem)=(300, 64, 64)
# Epoch : 100
# Epoch : 200
# Epoch : 500
# Epoch : 750
# Epoch : 1000
# Epoch : 1250
# Epoch : 1500
# Epoch : 2000

# %%
j, k = 0, 0
fig, axes = plt.subplots(
    nb_rows,
    size_row,
    figsize=(size_per_fig * size_row, size_per_fig * nb_rows),
)

for i in range(len(indices)):
    if k == size_row:
        k = 0
        j += 1
    sns.histplot(
        data=errors_fno[indices[i]],
        kde=True,
        bins=20,
        color=colors[2],
        edgecolor="k",
        log_scale=True,
        label=str(epochs[indices[i]]),
        stat="proportion",
        legend=True,
        ax=axes[j, k],
    )
    axes[j, k].set_xlabel("$L^2$ relative error")
    axes[j, k].legend()
    axes[j, k].set_xlim(3e-4, 1e-1)
    axes[j, k].set_ylim(0.0, 0.17)
    k += 1

plt.tight_layout()
if save_figs:
    plt.savefig(f"./images_{nb_data}/histograms_new_data_L2.png")
plt.show()

# %%
plt.figure(figsize=(10, 5))

"""
On crée des dataframe de la forme
|epoch|error|norm|
où type est L2 ou Linf et epoch est un multiple de 250
"""

size_val = len(errors_fno[0])

epoch_repeat = np.array([])
for epoch in epochs:
    tab = np.repeat(str(epoch), size_val)
    epoch_repeat = np.concatenate([epoch_repeat, tab], axis=0)

tab_L2 = np.repeat(["$L^2$"], size_val * len(epochs))

errors_L2_flatten = np.array(errors_fno).flatten()

df_array_L2 = np.stack([epoch_repeat, errors_L2_flatten, tab_L2], axis=0)

df_array = np.concatenate([df_array_L2], axis=1)

name = ["Epochs", "Error", "Norm"]
df_errors = pd.DataFrame(df_array.transpose(), columns=name)
df_errors = df_errors.astype(
    {"Epochs": "int", "Error": "float64", "Norm": "category"}
)

sns.boxplot(
    data=df_errors, x="Epochs", y="Error", hue="Norm", dodge=True
)  # ,palette="ch:s=.25,rot=-.25"
plt.yscale("log")
plt.ylabel("Relative error")
plt.tight_layout()

save_figs = True
if save_figs:
    plt.savefig(f"./images_{nb_data}/boxplots_new_data_L2.png")
plt.show()

# %%
errors, times_fno = [], []

for j in epochs_means:
    print(f"Epoch : {j}")
    agent.model.load_weights(f"./models_{nb_data}/model_{j}/model_weights")
    L2_error_fno = []
    Temps_fno = []
    X = generate_manual_new_data_numpy(Phi, F / data.max_norm_F, G)
    Y_pred = agent.model.call(X)

    domain = X[:, :, :, -2]
    boundary = X[:, :, :, -1]
    nb_vert = np.shape(boundary)[1]
    domain_prop = tf.reduce_sum(domain, axis=[1, 2]) / nb_vert**2
    boundary_prop = tf.reduce_sum(boundary, axis=[1, 2]) / nb_vert**2
    diff = (
        W_phi_fem[:, :, :] * X[:, :, :, 1]
        + G
        - (Y_pred[:, :, :, 0] * X[:, :, :, 1] + G)
    )

    L2_error_fno = tf.sqrt(
        tf.reduce_mean(
            (diff**2) * X[:, :, :, -2] / (domain_prop[:, None, None]),
            axis=[1, 2],
        )
        / tf.reduce_mean(
            ((W_phi_fem * X[:, :, :, 1] + G) ** 2)
            * X[:, :, :, -2]
            / (domain_prop[:, None, None]),
            axis=[1, 2],
        )
    )

    errors.append(L2_error_fno)
# Out:
# Epoch : 50
# Epoch : 100
# Epoch : 150
# Epoch : 200
# Epoch : 250
# Epoch : 300
# Epoch : 350
# Epoch : 400
# Epoch : 450
# Epoch : 500
# Epoch : 550
# Epoch : 600
# Epoch : 650
# Epoch : 700
# Epoch : 750
# Epoch : 800
# Epoch : 850
# Epoch : 900
# Epoch : 950
# Epoch : 1000
# Epoch : 1050
# Epoch : 1100
# Epoch : 1150
# Epoch : 1200
# Epoch : 1250
# Epoch : 1300
# Epoch : 1350
# Epoch : 1400
# Epoch : 1450
# Epoch : 1500
# Epoch : 1550
# Epoch : 1600
# Epoch : 1650
# Epoch : 1700
# Epoch : 1750
# Epoch : 1800
# Epoch : 1850
# Epoch : 1900
# Epoch : 1950
# Epoch : 2000

# %%
means = np.mean(errors, axis=1)
standard_deviation = np.std(errors, axis=1)
maxs = np.max(errors, axis=1)
mins = np.min(errors, axis=1)

plt.figure(figsize=(8, 4))
plt.subplot(1, 2, 1)
plt.semilogy(epochs_means, means, "-+", label="Mean")
plt.xlabel("Epochs")
plt.ylabel("$L^2$ relative error")
plt.semilogy(
    epochs_means, standard_deviation, "-+", label="Standard deviation"
)
plt.xlabel("Epochs")
plt.ylabel("$L^2$ relative error")
plt.grid(True, "both", "both")
plt.legend()

plt.subplot(1, 2, 2)
plt.semilogy(epochs_means, maxs, "-+", label="Maximum")
plt.semilogy(epochs_means, mins, "-+", label="Minimum")
plt.grid(True, "both", "both")
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("$L^2$ relative error")
plt.tight_layout()

if save_figs:
    plt.savefig(
        f"./images_{nb_data}/min_mean_max_L2_error_epochs_new_data.png"
    )
plt.show()
