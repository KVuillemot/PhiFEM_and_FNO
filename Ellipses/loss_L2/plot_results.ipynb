# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import os

os.environ["TF_CPP_MIN_LOG_LEVEL"] = "2"
import tensorflow as tf

seed = 2023
random.seed(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.experimental.numpy.random.seed(seed)
os.environ["TF_CUDNN_DETERMINISTIC"] = "1"
os.environ["TF_DETERMINISTIC_OPS"] = "1"
# Set a fixed value for the hash seed
os.environ["PYTHONHASHSEED"] = str(seed)
import dolfin as df
import time
from utils import *
from utils_training import *
import prepare_data
import seaborn as sns
from mpl_toolkits.axes_grid1 import make_axes_locatable
import pandas as pd

sns.set_theme()
sns.set_context("paper")
sns.set(rc={"xtick.bottom": True, "ytick.left": True})
colors = sns.color_palette("mako").as_hex()
my_cmap = sns.color_palette("viridis", as_cmap=True)
# Out:
# Invalid MIT-MAGIC-COOKIE-1 key

# %%
save_figs = True
small_data = False
data = DataLoader(small_data)
agent = Agent(data, small_data)

if not (os.path.exists(f"./images/")) and save_figs:
    os.makedirs(f"./images/")

file = open("./models/best_model/best_epoch.txt")
for y in file.read().split(" "):
    if y.isdigit():
        best_epoch = int(y)
epochs = [50, 100, 250, 500, 1000, 1500, 2000, best_epoch]
print(len(epochs))
print(epochs)

indices = list(range(0, len(epochs)))
size_per_fig = 4
nb_rows = 2
size_row = int(len(indices) / nb_rows)
# Out:
# max_norm_F : 65.79521
# data_size,nb_val,nb_train: 1500 187 1313
# data shape: (None, 64, 64, 4)
# on val data: residues_interior =  1.4574209e-05
# FNO2d model created with hyperparameters : modes:20, width:20, pad_prop:0.05
# 8
# [50, 100, 250, 500, 1000, 1500, 2000, 1910]

# %% [markdown]
# # Minimal error on the validation sample

# %% [markdown]
# We compute the error in the norm
# $$
# \sqrt{\frac{\text{mse}( \omega \phi_h (\mathcal{G}_\theta (\phi_h, f_h, g_h) - w_h))}{\text{mse}(\omega(\phi_h w_h + g_h))}} \,,
# $$
# and determine the problem giving the minimal error on the validation sample.

# %%
i = best_epoch
agent.model.load_weights(f"./models/model_{i}/model_weights")
X_val, Y_val = agent.data.X_val, agent.data.Y_val
Y_pred = agent.model.call(X_val)
domain = X_val[:, :, :, -1]
nb_vert = np.shape(domain)[1]
domain_prop = tf.reduce_sum(domain, axis=[1, 2]) / nb_vert**2

diff = (
    Y_val * X_val[:, :, :, 1, None]
    + X_val[:, :, :, 2, None]
    - (Y_pred * X_val[:, :, :, 1, None] + X_val[:, :, :, 2, None])
)

L2_error = tf.sqrt(
    tf.reduce_mean(
        (diff**2) * X_val[:, :, :, -1, None],
        axis=[1, 2, 3],
    )
    / tf.reduce_mean(
        ((Y_val * X_val[:, :, :, 1, None] + X_val[:, :, :, 2, None]) ** 2)
        * X_val[:, :, :, -1, None],
        axis=[1, 2, 3],
    )
)

argmin = np.argmin(L2_error)
print(argmin)
sorted_min = sorted(range(len(L2_error)), key=lambda k: L2_error[k])
minimal_errors = sorted_min[:1]
print(minimal_errors)

Params = np.load(f"../data/agentParams.npy")
data_size = np.shape(Params)[0]
nb_val = np.shape(data.X_val)[0]
nb_train = data_size - nb_val
params_val = Params[nb_train:]

for i in minimal_errors:
    X = data.X_val[i, :, :]
    F = X[:, :, 0] * data.max_norm_F
    W_ref = data.Y_val[i]
    Y = agent.model.call(X[None, :, :, :])
    domains_nan = X[:, :, -1].numpy()
    domains_nan[domains_nan == 0] = np.nan

    plt.figure(figsize=(16, 4))

    ax1 = plt.subplot(141)
    img = ax1.imshow(
        F * domains_nan, cmap=my_cmap, aspect="equal", origin="lower"
    )
    divider = make_axes_locatable(ax1)
    cax = divider.append_axes("bottom", size="5%", pad=0.3)
    ax1.grid(False)
    ax1.set_title(r"$f$", fontsize=20)
    plt.colorbar(img, cax=cax, orientation="horizontal")

    ax2 = plt.subplot(142)
    img = ax2.imshow(
        (X[:, :, 2]) * domains_nan,
        cmap=my_cmap,
        aspect="equal",
        origin="lower",
    )
    divider = make_axes_locatable(ax2)
    cax = divider.append_axes("bottom", size="5%", pad=0.3)
    ax2.grid(False)
    ax2.set_title(r"$g$", fontsize=20)
    plt.colorbar(img, cax=cax, orientation="horizontal")

    ax3 = plt.subplot(143)
    img = ax3.imshow(
        (Y[0, :, :, 0] * X[:, :, 1] + X[:, :, 2]) * domains_nan,
        cmap=my_cmap,
        aspect="equal",
        origin="lower",
    )
    divider = make_axes_locatable(ax3)
    cax = divider.append_axes("bottom", size="5%", pad=0.3)
    ax3.grid(False)
    ax3.set_title(r"$\phi w_{pred} + g$", fontsize=20)
    plt.colorbar(img, cax=cax, orientation="horizontal")

    ax4 = plt.subplot(144)
    img = ax4.imshow(
        (W_ref[:, :, 0] * X[:, :, 1] + X[:, :, 2]) * domains_nan,
        cmap=my_cmap,
        aspect="equal",
        origin="lower",
    )
    divider = make_axes_locatable(ax4)
    cax = divider.append_axes("bottom", size="5%", pad=0.3)
    ax4.grid(False)
    ax4.set_title(r"$\phi w_{ref} + g$", fontsize=20)
    plt.colorbar(img, cax=cax, orientation="horizontal")

    if save_figs:
        plt.savefig(f"./images/best_prediction_{L2_error[i]:6f}.png")
    plt.show()

    params = params_val[i]
    print(
        f"(mu0, mu1, sigma, x_0, y_0, lx, ly, theta, alpha, beta) = {params}"
    )
    print(f"{L2_error[i]:6f}")
# Out:
# 161
# [161]
# (mu0, mu1, sigma, x_0, y_0, lx, ly, theta, alpha, beta) = [ 0.63507455  0.38582049  0.28547313  0.58607465  0.41008128  0.30043293
#   0.27957654  1.20604371  0.65553255 -0.1462666 ]
# 0.001004

# %% [markdown]
# # Relative errors with respect to a $\phi$-FEM solution

# %% [markdown]
# ## On the validation set

# %% [markdown]
# We then compute the errors (using the same norm and the $L^\infty$ norm) for the different models, to analyze the convergence of the method on the validation sample.

# %%
L2_errors = []
Linf_errors = []

for i in epochs:
    agent.model.load_weights(f"./models/model_{i}/model_weights")
    X_val, Y_val = agent.data.X_val, agent.data.Y_val
    Y_pred = agent.model.call(X_val)
    domain = X_val[:, :, :, -1]
    nb_vert = np.shape(domain)[1]
    domain_prop = tf.reduce_sum(domain, axis=[1, 2]) / nb_vert**2

    diff = (
        Y_val * X_val[:, :, :, 1, None]
        + X_val[:, :, :, 2, None]
        - (Y_pred * X_val[:, :, :, 1, None] + X_val[:, :, :, 2, None])
    )

    val = tf.sqrt(
        tf.reduce_mean(
            (diff**2) * X_val[:, :, :, -1, None],
            axis=[1, 2, 3],
        )
        / tf.reduce_mean(
            ((Y_val * X_val[:, :, :, 1, None] + X_val[:, :, :, 2, None]) ** 2)
            * X_val[:, :, :, -1, None],
            axis=[1, 2, 3],
        )
    )

    L2_errors.append(val)
    Linf_errors.append(
        np.max(
            np.max(np.absolute(diff * X_val[:, :, :, -1, None]), axis=1),
            axis=1,
        )
        / np.max(
            np.max(
                np.absolute(
                    (Y_val * X_val[:, :, :, 1, None] + X_val[:, :, :, 2, None])
                    * X_val[:, :, :, -1, None]
                ),
                axis=1,
            ),
            axis=1,
        )
    )

L2_errors = np.array(L2_errors)
Linf_errors = np.array(Linf_errors)
Linf_errors = np.reshape(Linf_errors, (np.shape(L2_errors)))

# %%
j, k = 0, 0
fig, axes = plt.subplots(
    nb_rows,
    size_row,
    figsize=(size_per_fig * size_row, size_per_fig * nb_rows),
)

for i in range(len(indices)):
    if k == size_row:
        k = 0
        j += 1

    if epochs[indices[i]] == best_epoch:
        color = "firebrick"
    else:
        color = colors[2]
    sns.histplot(
        data=L2_errors[indices[i]],
        kde=True,
        bins=30,
        color=color,
        edgecolor="k",
        log_scale=True,
        label=str(epochs[indices[i]]),
        stat="proportion",
        legend=True,
        ax=axes[j, k],
    )
    axes[j, k].set_xlabel("$L^2$ relative error")
    axes[j, k].legend()
    axes[j, k].set_xlim(1e-4, 2e-1)
    axes[j, k].set_ylim(0.0, 0.11)
    k += 1

plt.tight_layout()
if save_figs:
    plt.savefig(f"./images/histograms_validation_L2.png")
plt.show()

# %%
j, k = 0, 0
fig, axes = plt.subplots(
    nb_rows,
    size_row,
    figsize=(size_per_fig * size_row, size_per_fig * nb_rows),
)

for i in range(len(indices)):
    if k == size_row:
        k = 0
        j += 1

    if epochs[indices[i]] == best_epoch:
        color = "firebrick"
    else:
        color = colors[2]
    sns.histplot(
        data=Linf_errors[indices[i]],
        kde=True,
        bins=30,
        color=color,
        edgecolor="k",
        log_scale=True,
        label=str(epochs[indices[i]]),
        stat="proportion",
        legend=True,
        ax=axes[j, k],
    )
    axes[j, k].set_xlabel("$L^\infty$ relative error")
    axes[j, k].legend()
    axes[j, k].set_xlim(1e-4, 1e-1)
    axes[j, k].set_ylim(0.0, 0.11)
    k += 1

plt.tight_layout()
if save_figs:
    plt.savefig(f"./images/histograms_validation_Linf.png")
plt.show()

# %%
plt.figure(figsize=(10, 5))

size_val = len(L2_errors[0])

epoch_repeat = np.array([])
for epoch in epochs:
    tab = np.repeat(str(epoch), size_val)
    epoch_repeat = np.concatenate([epoch_repeat, tab], axis=0)

tab_L2 = np.repeat(["$L^2$"], size_val * len(epochs))

errors_L2_flatten = np.array(L2_errors).flatten()

df_array_L2 = np.stack([epoch_repeat, errors_L2_flatten, tab_L2], axis=0)

tab_Linf = np.repeat(["$L^\infty$"], size_val * len(epochs))
errors_Linf_flatten = np.array(Linf_errors).flatten()
df_array_Linf = np.stack([epoch_repeat, errors_Linf_flatten, tab_Linf], axis=0)

df_array = np.concatenate([df_array_L2, df_array_Linf], axis=1)

name = ["Epochs", "Error", "Norm"]
df_errors = pd.DataFrame(df_array.transpose(), columns=name)
df_errors = df_errors.astype(
    {"Epochs": "int", "Error": "float64", "Norm": "category"}
)

sns.boxplot(
    data=df_errors,
    x="Epochs",
    y="Error",
    hue="Norm",
    dodge=True,
)
plt.yscale("log")
plt.ylabel("Relative error", fontsize=15)
plt.xlabel("Epochs", fontsize=15)
plt.tight_layout()

if save_figs:
    plt.savefig(f"./images/boxplots_validation_L2_Linf.png")
plt.show()

# %%
palette = sns.cubehelix_palette(n_colors=7, start=0.25, rot=-0.25, gamma=0.5)
palette = palette.as_hex()
palette.append("#b22222")
palette = sns.color_palette(palette)

plt.figure(figsize=(10, 5))
errors = np.array(L2_errors[:])
print(np.shape(errors))
dataframe = pd.DataFrame(errors.transpose(), columns=epochs)

sns.boxplot(data=dataframe, palette=palette)
plt.xlabel("Training epochs")
plt.ylabel("$L^2$ relative error")
plt.yscale("log")
plt.grid(True, "both", "y")
plt.tight_layout()
if save_figs:
    plt.savefig(f"./images/boxplots_validation_epochs_L2_error.png")
plt.show()
# Out:
# (8, 187)

# %%
epochs_means = list(i * 40 for i in range(1, 51))
epochs_means.append(best_epoch)

print(len(epochs_means))
print(epochs_means)

L2_errors = []
Linf_errors = []

for i in epochs_means:
    agent.model.load_weights(f"./models/model_{i}/model_weights")
    X_val, Y_val = agent.data.X_val, agent.data.Y_val
    Y_pred = agent.model.call(X_val)
    domain = X_val[:, :, :, -1]
    nb_vert = np.shape(domain)[1]
    domain_prop = tf.reduce_sum(domain, axis=[1, 2]) / nb_vert**2

    diff = (
        Y_val * X_val[:, :, :, 1, None]
        + X_val[:, :, :, 2, None]
        - (Y_pred * X_val[:, :, :, 1, None] + X_val[:, :, :, 2, None])
    )

    val = tf.sqrt(
        tf.reduce_mean(
            (diff**2) * X_val[:, :, :, -1, None],
            axis=[1, 2, 3],
        )
        / tf.reduce_mean(
            ((Y_val * X_val[:, :, :, 1, None] + X_val[:, :, :, 2, None]) ** 2)
            * X_val[:, :, :, -1, None],
            axis=[1, 2, 3],
        )
    )

    L2_errors.append(val)
    Linf_errors.append(
        np.max(
            np.max(np.absolute(diff * X_val[:, :, :, -1, None]), axis=1),
            axis=1,
        )
        / np.max(
            np.max(
                np.absolute(
                    (Y_val * X_val[:, :, :, 1, None] + X_val[:, :, :, 2, None])
                    * X_val[:, :, :, -1, None]
                ),
                axis=1,
            ),
            axis=1,
        )
    )
# Out:
# 51
# [40, 80, 120, 160, 200, 240, 280, 320, 360, 400, 440, 480, 520, 560, 600, 640, 680, 720, 760, 800, 840, 880, 920, 960, 1000, 1040, 1080, 1120, 1160, 1200, 1240, 1280, 1320, 1360, 1400, 1440, 1480, 1520, 1560, 1600, 1640, 1680, 1720, 1760, 1800, 1840, 1880, 1920, 1960, 2000, 1910]

# %%
means = np.mean(L2_errors, axis=1)
standard_deviation = np.std(L2_errors, axis=1)
maxs = np.max(L2_errors, axis=1)
mins = np.min(L2_errors, axis=1)

plt.figure(figsize=(8, 3))
plt.subplot(1, 2, 1)
plt.semilogy(epochs_means[:-1], means[:-1], "-+", label="Mean")
plt.semilogy(
    epochs_means[:-1],
    standard_deviation[:-1],
    "-+",
    label="Standard deviation",
)
plt.semilogy(epochs_means[-1], means[-1], "x", c="firebrick", markersize=6)
plt.semilogy(
    epochs_means[-1], standard_deviation[-1], "x", c="firebrick", markersize=6
)
plt.xlabel("Epochs")
plt.grid(True, "both", "both")
plt.legend()

plt.subplot(1, 2, 2)
plt.semilogy(epochs_means[:-1], maxs[:-1], "-+", label="Maximum")
plt.semilogy(epochs_means[:-1], mins[:-1], "-+", label="Minimum")
plt.semilogy(epochs_means[-1], maxs[-1], "x", c="firebrick", markersize=6)
plt.semilogy(epochs_means[-1], mins[-1], "x", c="firebrick", markersize=6)
plt.grid(True, "both", "both")
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("$L^2$ relative error")
plt.tight_layout()

if save_figs:
    plt.savefig(f"./images/min_mean_max_L2_error_epochs.png")
plt.show()

# %% [markdown]
# ## On a new test dataset

# %% [markdown]
# We now move to the case of new data. We generate a new dataset and compute the error between a $\phi$-FEM solution of the dataset and a prediction of the trained model.

# %%
from generate_data import PhiFemSolver
from prepare_data import set_seed

set_seed(2025)

# %%
F, Phi, G, params = create_FG_numpy(300, 64)
solver = PhiFemSolver(nb_cell=64 - 1, params=params)
W_phi_fem = solver.solve_several()
print(f"{np.shape(W_phi_fem)=}")

L2_errors_fno = []

for j in epochs:
    print(f"Epoch : {j}")
    agent.model.load_weights(f"./models/model_{j}/model_weights")
    L2_error_fno = []
    X = generate_manual_new_data_numpy(Phi, F / data.max_norm_F, G)
    Y_pred = agent.model.call(X)

    domain = X[:, :, :, -1]
    nb_vert = np.shape(domain)[1]
    domain_prop = tf.reduce_sum(domain, axis=[1, 2]) / nb_vert**2
    diff = (
        W_phi_fem[:, :, :] * X[:, :, :, 1]
        + G
        - (Y_pred[:, :, :, 0] * X[:, :, :, 1] + G)
    )

    L2_error_fno = tf.sqrt(
        tf.reduce_mean(
            (diff**2) * X[:, :, :, -1] / (domain_prop[:, None, None]),
            axis=[1, 2],
        )
        / tf.reduce_mean(
            ((W_phi_fem * X[:, :, :, 1] + G) ** 2)
            * X[:, :, :, -1]
            / (domain_prop[:, None, None]),
            axis=[1, 2],
        )
    )

    L2_errors_fno.append(L2_error_fno)
# Out:
# 0/300:num of cell in the ghost penalty: 272
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 1/300:Computed bounding box tree with 4741 nodes for 2371 points.
# num of cell in the ghost penalty: 190
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 2/300:Computed bounding box tree with 2595 nodes for 1298 points.
# num of cell in the ghost penalty: 220
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3509 nodes for 1755 points.
# 3/300:num of cell in the ghost penalty: 214
# Solving linear variational problem.
# 4/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3535 nodes for 1768 points.
# num of cell in the ghost penalty: 352
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 7977 nodes for 3989 points.
# 5/300:num of cell in the ghost penalty: 236
# Solving linear variational problem.
# 6/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 4113 nodes for 2057 points.
# num of cell in the ghost penalty: 296
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 7/300:Computed bounding box tree with 6181 nodes for 3091 points.
# num of cell in the ghost penalty: 250
# Solving linear variational problem.
# 8/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 4291 nodes for 2146 points.
# num of cell in the ghost penalty: 282
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 9/300:Computed bounding box tree with 5627 nodes for 2814 points.
# num of cell in the ghost penalty: 206
# Solving linear variational problem.
# 10/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3331 nodes for 1666 points.
# num of cell in the ghost penalty: 344
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 11/300:Computed bounding box tree with 8201 nodes for 4101 points.
# num of cell in the ghost penalty: 222
# Solving linear variational problem.
# 12/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3655 nodes for 1828 points.
# num of cell in the ghost penalty: 302
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 13/300:Computed bounding box tree with 5351 nodes for 2676 points.
# num of cell in the ghost penalty: 224
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 14/300:Computed bounding box tree with 3901 nodes for 1951 points.
# num of cell in the ghost penalty: 194
# Solving linear variational problem.
# 15/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 2919 nodes for 1460 points.
# num of cell in the ghost penalty: 268
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 16/300:Computed bounding box tree with 5077 nodes for 2539 points.
# num of cell in the ghost penalty: 240
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 17/300:Computed bounding box tree with 4105 nodes for 2053 points.
# num of cell in the ghost penalty: 244
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 18/300:Computed bounding box tree with 4249 nodes for 2125 points.
# num of cell in the ghost penalty: 328
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 7625 nodes for 3813 points.
# 19/300:num of cell in the ghost penalty: 262
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 20/300:Computed bounding box tree with 4251 nodes for 2126 points.
# num of cell in the ghost penalty: 262
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 21/300:Computed bounding box tree with 4875 nodes for 2438 points.
# num of cell in the ghost penalty: 296
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 22/300:Computed bounding box tree with 5961 nodes for 2981 points.
# num of cell in the ghost penalty: 264
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 23/300:Computed bounding box tree with 4757 nodes for 2379 points.
# num of cell in the ghost penalty: 232
# Solving linear variational problem.
# 24/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3245 nodes for 1623 points.
# num of cell in the ghost penalty: 206
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 25/300:Computed bounding box tree with 3155 nodes for 1578 points.
# num of cell in the ghost penalty: 300
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 26/300:Computed bounding box tree with 6417 nodes for 3209 points.
# num of cell in the ghost penalty: 206
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 27/300:Computed bounding box tree with 2851 nodes for 1426 points.
# num of cell in the ghost penalty: 238
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 28/300:Computed bounding box tree with 4071 nodes for 2036 points.
# num of cell in the ghost penalty: 246
# Solving linear variational problem.
# 29/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 4623 nodes for 2312 points.
# num of cell in the ghost penalty: 232
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 30/300:Computed bounding box tree with 3693 nodes for 1847 points.
# num of cell in the ghost penalty: 196
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 31/300:Computed bounding box tree with 2777 nodes for 1389 points.
# num of cell in the ghost penalty: 314
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 32/300:Computed bounding box tree with 6523 nodes for 3262 points.
# num of cell in the ghost penalty: 252
# Solving linear variational problem.
# 33/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 4533 nodes for 2267 points.
# num of cell in the ghost penalty: 242
# Solving linear variational problem.
# 34/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3551 nodes for 1776 points.
# num of cell in the ghost penalty: 232
# Solving linear variational problem.
# 35/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3477 nodes for 1739 points.
# num of cell in the ghost penalty: 250
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 36/300:Computed bounding box tree with 4543 nodes for 2272 points.
# num of cell in the ghost penalty: 278
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 5543 nodes for 2772 points.
# 37/300:num of cell in the ghost penalty: 214
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 38/300:Computed bounding box tree with 3243 nodes for 1622 points.
# num of cell in the ghost penalty: 226
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 39/300:Computed bounding box tree with 3491 nodes for 1746 points.
# num of cell in the ghost penalty: 218
# Solving linear variational problem.
# 40/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 2999 nodes for 1500 points.
# num of cell in the ghost penalty: 280
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 41/300:Computed bounding box tree with 4769 nodes for 2385 points.
# num of cell in the ghost penalty: 190
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 2575 nodes for 1288 points.
# 42/300:num of cell in the ghost penalty: 208
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 2865 nodes for 1433 points.
# 43/300:num of cell in the ghost penalty: 198
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 44/300:Computed bounding box tree with 3067 nodes for 1534 points.
# num of cell in the ghost penalty: 248
# Solving linear variational problem.
# 45/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 4305 nodes for 2153 points.
# num of cell in the ghost penalty: 188
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 46/300:Computed bounding box tree with 2581 nodes for 1291 points.
# num of cell in the ghost penalty: 254
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 47/300:Computed bounding box tree with 4771 nodes for 2386 points.
# num of cell in the ghost penalty: 268
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 48/300:Computed bounding box tree with 4949 nodes for 2475 points.
# num of cell in the ghost penalty: 236
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 49/300:Computed bounding box tree with 3661 nodes for 1831 points.
# num of cell in the ghost penalty: 300
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 50/300:Computed bounding box tree with 6761 nodes for 3381 points.
# num of cell in the ghost penalty: 242
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 51/300:Computed bounding box tree with 4371 nodes for 2186 points.
# num of cell in the ghost penalty: 236
# Solving linear variational problem.
# 52/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 4085 nodes for 2043 points.
# num of cell in the ghost penalty: 240
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 53/300:Computed bounding box tree with 4401 nodes for 2201 points.
# num of cell in the ghost penalty: 246
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 54/300:Computed bounding box tree with 4643 nodes for 2322 points.
# num of cell in the ghost penalty: 212
# Solving linear variational problem.
# 55/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3305 nodes for 1653 points.
# num of cell in the ghost penalty: 228
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 56/300:Computed bounding box tree with 3685 nodes for 1843 points.
# num of cell in the ghost penalty: 346
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 57/300:Computed bounding box tree with 8059 nodes for 4030 points.
# num of cell in the ghost penalty: 214
# Solving linear variational problem.
# 58/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3227 nodes for 1614 points.
# num of cell in the ghost penalty: 338
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 59/300:Computed bounding box tree with 7691 nodes for 3846 points.
# num of cell in the ghost penalty: 240
# Solving linear variational problem.
# 60/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 4129 nodes for 2065 points.
# num of cell in the ghost penalty: 286
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 61/300:Computed bounding box tree with 5723 nodes for 2862 points.
# num of cell in the ghost penalty: 246
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 4423 nodes for 2212 points.
# 62/300:num of cell in the ghost penalty: 204
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 63/300:Computed bounding box tree with 2785 nodes for 1393 points.
# num of cell in the ghost penalty: 248
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 64/300:Computed bounding box tree with 4101 nodes for 2051 points.
# num of cell in the ghost penalty: 232
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 65/300:Computed bounding box tree with 3765 nodes for 1883 points.
# num of cell in the ghost penalty: 284
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 66/300:Computed bounding box tree with 5281 nodes for 2641 points.
# num of cell in the ghost penalty: 256
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 67/300:Computed bounding box tree with 4657 nodes for 2329 points.
# num of cell in the ghost penalty: 216
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 68/300:Computed bounding box tree with 3265 nodes for 1633 points.
# num of cell in the ghost penalty: 238
# Solving linear variational problem.
# 69/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 4247 nodes for 2124 points.
# num of cell in the ghost penalty: 254
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 70/300:Computed bounding box tree with 4763 nodes for 2382 points.
# num of cell in the ghost penalty: 204
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 71/300:Computed bounding box tree with 3297 nodes for 1649 points.
# num of cell in the ghost penalty: 218
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3011 nodes for 1506 points.
# 72/300:num of cell in the ghost penalty: 222
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 73/300:Computed bounding box tree with 3639 nodes for 1820 points.
# num of cell in the ghost penalty: 234
# Solving linear variational problem.
# 74/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3715 nodes for 1858 points.
# num of cell in the ghost penalty: 288
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 75/300:Computed bounding box tree with 5789 nodes for 2895 points.
# num of cell in the ghost penalty: 228
# Solving linear variational problem.
# 76/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3917 nodes for 1959 points.
# num of cell in the ghost penalty: 276
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 77/300:Computed bounding box tree with 5113 nodes for 2557 points.
# num of cell in the ghost penalty: 284
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 5573 nodes for 2787 points.
# 78/300:num of cell in the ghost penalty: 294
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 79/300:Computed bounding box tree with 6115 nodes for 3058 points.
# num of cell in the ghost penalty: 220
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 80/300:Computed bounding box tree with 3397 nodes for 1699 points.
# num of cell in the ghost penalty: 218
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3535 nodes for 1768 points.
# 81/300:num of cell in the ghost penalty: 288
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 82/300:Computed bounding box tree with 5181 nodes for 2591 points.
# num of cell in the ghost penalty: 216
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 83/300:Computed bounding box tree with 3285 nodes for 1643 points.
# num of cell in the ghost penalty: 268
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 84/300:Computed bounding box tree with 5145 nodes for 2573 points.
# num of cell in the ghost penalty: 220
# Solving linear variational problem.
# 85/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3333 nodes for 1667 points.
# num of cell in the ghost penalty: 238
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 86/300:Computed bounding box tree with 4131 nodes for 2066 points.
# num of cell in the ghost penalty: 246
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 87/300:Computed bounding box tree with 4167 nodes for 2084 points.
# num of cell in the ghost penalty: 276
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 88/300:Computed bounding box tree with 5345 nodes for 2673 points.
# num of cell in the ghost penalty: 242
# Solving linear variational problem.
# 89/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3751 nodes for 1876 points.
# num of cell in the ghost penalty: 196
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 90/300:Computed bounding box tree with 2997 nodes for 1499 points.
# num of cell in the ghost penalty: 188
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 91/300:Computed bounding box tree with 2597 nodes for 1299 points.
# num of cell in the ghost penalty: 194
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 92/300:Computed bounding box tree with 2699 nodes for 1350 points.
# num of cell in the ghost penalty: 270
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 93/300:Computed bounding box tree with 5639 nodes for 2820 points.
# num of cell in the ghost penalty: 250
# Solving linear variational problem.
# 94/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3999 nodes for 2000 points.
# num of cell in the ghost penalty: 306
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 95/300:Computed bounding box tree with 7083 nodes for 3542 points.
# num of cell in the ghost penalty: 236
# Solving linear variational problem.
# 96/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 4029 nodes for 2015 points.
# num of cell in the ghost penalty: 244
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 97/300:Computed bounding box tree with 4249 nodes for 2125 points.
# num of cell in the ghost penalty: 220
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3481 nodes for 1741 points.
# 98/300:num of cell in the ghost penalty: 260
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 99/300:Computed bounding box tree with 4897 nodes for 2449 points.
# num of cell in the ghost penalty: 184
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 100/300:Computed bounding box tree with 2489 nodes for 1245 points.
# num of cell in the ghost penalty: 280
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 101/300:Computed bounding box tree with 5585 nodes for 2793 points.
# num of cell in the ghost penalty: 218
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 102/300:Computed bounding box tree with 3303 nodes for 1652 points.
# num of cell in the ghost penalty: 280
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 103/300:Computed bounding box tree with 5673 nodes for 2837 points.
# num of cell in the ghost penalty: 230
# Solving linear variational problem.
# 104/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3371 nodes for 1686 points.
# num of cell in the ghost penalty: 256
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 105/300:Computed bounding box tree with 4569 nodes for 2285 points.
# num of cell in the ghost penalty: 230
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 106/300:Computed bounding box tree with 3583 nodes for 1792 points.
# num of cell in the ghost penalty: 308
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 6317 nodes for 3159 points.
# 107/300:num of cell in the ghost penalty: 236
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 108/300:Computed bounding box tree with 4449 nodes for 2225 points.
# num of cell in the ghost penalty: 252
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 109/300:Computed bounding box tree with 4965 nodes for 2483 points.
# num of cell in the ghost penalty: 224
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 110/300:Computed bounding box tree with 3641 nodes for 1821 points.
# num of cell in the ghost penalty: 254
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 111/300:Computed bounding box tree with 4415 nodes for 2208 points.
# num of cell in the ghost penalty: 282
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 112/300:Computed bounding box tree with 5895 nodes for 2948 points.
# num of cell in the ghost penalty: 194
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 2623 nodes for 1312 points.
# 113/300:num of cell in the ghost penalty: 190
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 114/300:Computed bounding box tree with 2599 nodes for 1300 points.
# num of cell in the ghost penalty: 240
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 115/300:Computed bounding box tree with 4505 nodes for 2253 points.
# num of cell in the ghost penalty: 316
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 6905 nodes for 3453 points.
# 116/300:num of cell in the ghost penalty: 246
# Solving linear variational problem.
# 117/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 4415 nodes for 2208 points.
# num of cell in the ghost penalty: 312
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 6397 nodes for 3199 points.
# 118/300:num of cell in the ghost penalty: 216
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 119/300:Computed bounding box tree with 3589 nodes for 1795 points.
# num of cell in the ghost penalty: 204
# Solving linear variational problem.
# 120/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3013 nodes for 1507 points.
# num of cell in the ghost penalty: 218
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 121/300:Computed bounding box tree with 3307 nodes for 1654 points.
# num of cell in the ghost penalty: 260
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 122/300:Computed bounding box tree with 5141 nodes for 2571 points.
# num of cell in the ghost penalty: 288
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 123/300:Computed bounding box tree with 4857 nodes for 2429 points.
# num of cell in the ghost penalty: 266
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 4587 nodes for 2294 points.
# 124/300:num of cell in the ghost penalty: 272
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 5249 nodes for 2625 points.
# 125/300:num of cell in the ghost penalty: 206
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3103 nodes for 1552 points.
# 126/300:num of cell in the ghost penalty: 190
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 2539 nodes for 1270 points.
# 127/300:num of cell in the ghost penalty: 222
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 128/300:Computed bounding box tree with 3759 nodes for 1880 points.
# num of cell in the ghost penalty: 278
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 129/300:Computed bounding box tree with 5879 nodes for 2940 points.
# num of cell in the ghost penalty: 204
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 130/300:Computed bounding box tree with 2921 nodes for 1461 points.
# num of cell in the ghost penalty: 184
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 131/300:Computed bounding box tree with 2677 nodes for 1339 points.
# num of cell in the ghost penalty: 258
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 132/300:Computed bounding box tree with 4647 nodes for 2324 points.
# num of cell in the ghost penalty: 190
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 133/300:Computed bounding box tree with 2583 nodes for 1292 points.
# num of cell in the ghost penalty: 216
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 134/300:Computed bounding box tree with 3349 nodes for 1675 points.
# num of cell in the ghost penalty: 258
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 4879 nodes for 2440 points.
# 135/300:num of cell in the ghost penalty: 212
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 136/300:Computed bounding box tree with 3473 nodes for 1737 points.
# num of cell in the ghost penalty: 224
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 137/300:Computed bounding box tree with 3397 nodes for 1699 points.
# num of cell in the ghost penalty: 276
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 138/300:Computed bounding box tree with 5413 nodes for 2707 points.
# num of cell in the ghost penalty: 212
# Solving linear variational problem.
# 139/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3045 nodes for 1523 points.
# num of cell in the ghost penalty: 234
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3987 nodes for 1994 points.
# 140/300:num of cell in the ghost penalty: 242
# Solving linear variational problem.
# 141/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 4059 nodes for 2030 points.
# num of cell in the ghost penalty: 222
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 142/300:Computed bounding box tree with 3607 nodes for 1804 points.
# num of cell in the ghost penalty: 214
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 143/300:Computed bounding box tree with 3323 nodes for 1662 points.
# num of cell in the ghost penalty: 282
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 144/300:Computed bounding box tree with 5467 nodes for 2734 points.
# num of cell in the ghost penalty: 260
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 145/300:Computed bounding box tree with 4769 nodes for 2385 points.
# num of cell in the ghost penalty: 310
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 6919 nodes for 3460 points.
# 146/300:num of cell in the ghost penalty: 256
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 147/300:Computed bounding box tree with 4025 nodes for 2013 points.
# num of cell in the ghost penalty: 266
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 5031 nodes for 2516 points.
# 148/300:num of cell in the ghost penalty: 242
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 149/300:Computed bounding box tree with 4287 nodes for 2144 points.
# num of cell in the ghost penalty: 278
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 150/300:Computed bounding box tree with 5483 nodes for 2742 points.
# num of cell in the ghost penalty: 296
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 151/300:Computed bounding box tree with 6253 nodes for 3127 points.
# num of cell in the ghost penalty: 258
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 152/300:Computed bounding box tree with 5099 nodes for 2550 points.
# num of cell in the ghost penalty: 198
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 153/300:Computed bounding box tree with 2867 nodes for 1434 points.
# num of cell in the ghost penalty: 290
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 154/300:Computed bounding box tree with 6219 nodes for 3110 points.
# num of cell in the ghost penalty: 216
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3549 nodes for 1775 points.
# 155/300:num of cell in the ghost penalty: 260
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 4897 nodes for 2449 points.
# 156/300:num of cell in the ghost penalty: 238
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 157/300:Computed bounding box tree with 3591 nodes for 1796 points.
# num of cell in the ghost penalty: 338
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 158/300:Computed bounding box tree with 7951 nodes for 3976 points.
# num of cell in the ghost penalty: 222
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 159/300:Computed bounding box tree with 3791 nodes for 1896 points.
# num of cell in the ghost penalty: 322
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 160/300:Computed bounding box tree with 6967 nodes for 3484 points.
# num of cell in the ghost penalty: 280
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 161/300:Computed bounding box tree with 4985 nodes for 2493 points.
# num of cell in the ghost penalty: 278
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 162/300:Computed bounding box tree with 5163 nodes for 2582 points.
# num of cell in the ghost penalty: 232
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 163/300:Computed bounding box tree with 3529 nodes for 1765 points.
# num of cell in the ghost penalty: 202
# Solving linear variational problem.
# 164/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3019 nodes for 1510 points.
# num of cell in the ghost penalty: 246
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 165/300:Computed bounding box tree with 4419 nodes for 2210 points.
# num of cell in the ghost penalty: 294
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 6047 nodes for 3024 points.
# 166/300:num of cell in the ghost penalty: 250
# Solving linear variational problem.
# 167/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3687 nodes for 1844 points.
# num of cell in the ghost penalty: 310
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 7043 nodes for 3522 points.
# 168/300:num of cell in the ghost penalty: 200
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 2953 nodes for 1477 points.
# 169/300:num of cell in the ghost penalty: 256
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 170/300:Computed bounding box tree with 4737 nodes for 2369 points.
# num of cell in the ghost penalty: 282
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 171/300:Computed bounding box tree with 5383 nodes for 2692 points.
# num of cell in the ghost penalty: 182
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 172/300:Computed bounding box tree with 2507 nodes for 1254 points.
# num of cell in the ghost penalty: 288
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 5853 nodes for 2927 points.
# 173/300:num of cell in the ghost penalty: 186
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 174/300:Computed bounding box tree with 2591 nodes for 1296 points.
# num of cell in the ghost penalty: 292
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 175/300:Computed bounding box tree with 5789 nodes for 2895 points.
# num of cell in the ghost penalty: 290
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 176/300:Computed bounding box tree with 5931 nodes for 2966 points.
# num of cell in the ghost penalty: 250
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 177/300:Computed bounding box tree with 4359 nodes for 2180 points.
# num of cell in the ghost penalty: 214
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 178/300:Computed bounding box tree with 3315 nodes for 1658 points.
# num of cell in the ghost penalty: 222
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3723 nodes for 1862 points.
# 179/300:num of cell in the ghost penalty: 226
# Solving linear variational problem.
# 180/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3923 nodes for 1962 points.
# num of cell in the ghost penalty: 250
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 181/300:Computed bounding box tree with 4071 nodes for 2036 points.
# num of cell in the ghost penalty: 290
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 182/300:Computed bounding box tree with 6191 nodes for 3096 points.
# num of cell in the ghost penalty: 222
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 183/300:Computed bounding box tree with 3847 nodes for 1924 points.
# num of cell in the ghost penalty: 260
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 4789 nodes for 2395 points.
# 184/300:num of cell in the ghost penalty: 196
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 2789 nodes for 1395 points.
# 185/300:num of cell in the ghost penalty: 286
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 186/300:Computed bounding box tree with 5875 nodes for 2938 points.
# num of cell in the ghost penalty: 238
# Solving linear variational problem.
# 187/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3579 nodes for 1790 points.
# num of cell in the ghost penalty: 222
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3539 nodes for 1770 points.
# 188/300:num of cell in the ghost penalty: 276
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 189/300:Computed bounding box tree with 5349 nodes for 2675 points.
# num of cell in the ghost penalty: 180
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 190/300:Computed bounding box tree with 2337 nodes for 1169 points.
# num of cell in the ghost penalty: 274
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 191/300:Computed bounding box tree with 5391 nodes for 2696 points.
# num of cell in the ghost penalty: 268
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 192/300:Computed bounding box tree with 4325 nodes for 2163 points.
# num of cell in the ghost penalty: 234
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 193/300:Computed bounding box tree with 3919 nodes for 1960 points.
# num of cell in the ghost penalty: 246
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 194/300:Computed bounding box tree with 3791 nodes for 1896 points.
# num of cell in the ghost penalty: 196
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 2733 nodes for 1367 points.
# 195/300:num of cell in the ghost penalty: 254
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 196/300:Computed bounding box tree with 4439 nodes for 2220 points.
# num of cell in the ghost penalty: 286
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 197/300:Computed bounding box tree with 4691 nodes for 2346 points.
# num of cell in the ghost penalty: 286
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 198/300:Computed bounding box tree with 4587 nodes for 2294 points.
# num of cell in the ghost penalty: 298
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 199/300:Computed bounding box tree with 6491 nodes for 3246 points.
# num of cell in the ghost penalty: 322
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 200/300:Computed bounding box tree with 5907 nodes for 2954 points.
# num of cell in the ghost penalty: 200
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 201/300:Computed bounding box tree with 2925 nodes for 1463 points.
# num of cell in the ghost penalty: 206
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3047 nodes for 1524 points.
# 202/300:num of cell in the ghost penalty: 286
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 203/300:Computed bounding box tree with 4715 nodes for 2358 points.
# num of cell in the ghost penalty: 238
# Solving linear variational problem.
# 204/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 4143 nodes for 2072 points.
# num of cell in the ghost penalty: 356
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 8453 nodes for 4227 points.
# 205/300:num of cell in the ghost penalty: 244
# Solving linear variational problem.
# 206/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3817 nodes for 1909 points.
# num of cell in the ghost penalty: 270
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 4035 nodes for 2018 points.
# 207/300:num of cell in the ghost penalty: 232
# Solving linear variational problem.
# 208/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3937 nodes for 1969 points.
# num of cell in the ghost penalty: 304
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 209/300:Computed bounding box tree with 6569 nodes for 3285 points.
# num of cell in the ghost penalty: 198
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 210/300:Computed bounding box tree with 2795 nodes for 1398 points.
# num of cell in the ghost penalty: 196
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 211/300:Computed bounding box tree with 2761 nodes for 1381 points.
# num of cell in the ghost penalty: 240
# Solving linear variational problem.
# 212/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 4241 nodes for 2121 points.
# num of cell in the ghost penalty: 210
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 213/300:Computed bounding box tree with 3219 nodes for 1610 points.
# num of cell in the ghost penalty: 278
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 5215 nodes for 2608 points.
# 214/300:num of cell in the ghost penalty: 266
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 4959 nodes for 2480 points.
# 215/300:num of cell in the ghost penalty: 204
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 216/300:Computed bounding box tree with 2961 nodes for 1481 points.
# num of cell in the ghost penalty: 282
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 217/300:Computed bounding box tree with 5123 nodes for 2562 points.
# num of cell in the ghost penalty: 248
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 4825 nodes for 2413 points.
# 218/300:num of cell in the ghost penalty: 230
# Solving linear variational problem.
# 219/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3579 nodes for 1790 points.
# num of cell in the ghost penalty: 228
# Solving linear variational problem.
# 220/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3745 nodes for 1873 points.
# num of cell in the ghost penalty: 274
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 221/300:Computed bounding box tree with 5567 nodes for 2784 points.
# num of cell in the ghost penalty: 262
# Solving linear variational problem.
# 222/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 4591 nodes for 2296 points.
# num of cell in the ghost penalty: 254
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 223/300:Computed bounding box tree with 4467 nodes for 2234 points.
# num of cell in the ghost penalty: 210
# Solving linear variational problem.
# 224/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3171 nodes for 1586 points.
# num of cell in the ghost penalty: 224
# Solving linear variational problem.
# 225/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3617 nodes for 1809 points.
# num of cell in the ghost penalty: 228
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 226/300:Computed bounding box tree with 3325 nodes for 1663 points.
# num of cell in the ghost penalty: 228
# Solving linear variational problem.
# 227/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3745 nodes for 1873 points.
# num of cell in the ghost penalty: 218
# Solving linear variational problem.
# 228/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3447 nodes for 1724 points.
# num of cell in the ghost penalty: 206
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3095 nodes for 1548 points.
# 229/300:num of cell in the ghost penalty: 218
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 230/300:Computed bounding box tree with 3351 nodes for 1676 points.
# num of cell in the ghost penalty: 196
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 231/300:Computed bounding box tree with 2765 nodes for 1383 points.
# num of cell in the ghost penalty: 292
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 232/300:Computed bounding box tree with 4849 nodes for 2425 points.
# num of cell in the ghost penalty: 234
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 233/300:Computed bounding box tree with 4251 nodes for 2126 points.
# num of cell in the ghost penalty: 226
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 234/300:Computed bounding box tree with 3499 nodes for 1750 points.
# num of cell in the ghost penalty: 196
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 2985 nodes for 1493 points.
# 235/300:num of cell in the ghost penalty: 266
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 236/300:Computed bounding box tree with 4455 nodes for 2228 points.
# num of cell in the ghost penalty: 200
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 2749 nodes for 1375 points.
# 237/300:num of cell in the ghost penalty: 202
# Solving linear variational problem.
# 238/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 2839 nodes for 1420 points.
# num of cell in the ghost penalty: 274
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 239/300:Computed bounding box tree with 5495 nodes for 2748 points.
# num of cell in the ghost penalty: 240
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 240/300:Computed bounding box tree with 4029 nodes for 2015 points.
# num of cell in the ghost penalty: 218
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3271 nodes for 1636 points.
# 241/300:num of cell in the ghost penalty: 214
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 242/300:Computed bounding box tree with 3119 nodes for 1560 points.
# num of cell in the ghost penalty: 256
# Solving linear variational problem.
# 243/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 4597 nodes for 2299 points.
# num of cell in the ghost penalty: 266
# Solving linear variational problem.
# 244/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 4451 nodes for 2226 points.
# num of cell in the ghost penalty: 278
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 245/300:Computed bounding box tree with 4767 nodes for 2384 points.
# num of cell in the ghost penalty: 238
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 246/300:Computed bounding box tree with 4023 nodes for 2012 points.
# num of cell in the ghost penalty: 266
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 247/300:Computed bounding box tree with 5327 nodes for 2664 points.
# num of cell in the ghost penalty: 238
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 248/300:Computed bounding box tree with 3775 nodes for 1888 points.
# num of cell in the ghost penalty: 260
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 249/300:Computed bounding box tree with 4549 nodes for 2275 points.
# num of cell in the ghost penalty: 334
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 250/300:Computed bounding box tree with 6699 nodes for 3350 points.
# num of cell in the ghost penalty: 222
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3771 nodes for 1886 points.
# 251/300:num of cell in the ghost penalty: 304
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 6341 nodes for 3171 points.
# 252/300:num of cell in the ghost penalty: 304
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 253/300:Computed bounding box tree with 5277 nodes for 2639 points.
# num of cell in the ghost penalty: 276
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 254/300:Computed bounding box tree with 5045 nodes for 2523 points.
# num of cell in the ghost penalty: 312
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 255/300:Computed bounding box tree with 6141 nodes for 3071 points.
# num of cell in the ghost penalty: 248
# Solving linear variational problem.
# 256/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 4441 nodes for 2221 points.
# num of cell in the ghost penalty: 224
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3577 nodes for 1789 points.
# 257/300:num of cell in the ghost penalty: 236
# Solving linear variational problem.
# 258/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 4345 nodes for 2173 points.
# num of cell in the ghost penalty: 284
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 259/300:Computed bounding box tree with 5897 nodes for 2949 points.
# num of cell in the ghost penalty: 174
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 260/300:Computed bounding box tree with 2259 nodes for 1130 points.
# num of cell in the ghost penalty: 208
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3129 nodes for 1565 points.
# 261/300:num of cell in the ghost penalty: 222
# Solving linear variational problem.
# 262/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3447 nodes for 1724 points.
# num of cell in the ghost penalty: 206
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 263/300:Computed bounding box tree with 2975 nodes for 1488 points.
# num of cell in the ghost penalty: 208
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 264/300:Computed bounding box tree with 3129 nodes for 1565 points.
# num of cell in the ghost penalty: 264
# Solving linear variational problem.
# 265/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 4561 nodes for 2281 points.
# num of cell in the ghost penalty: 258
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 266/300:Computed bounding box tree with 4607 nodes for 2304 points.
# num of cell in the ghost penalty: 184
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 267/300:Computed bounding box tree with 2377 nodes for 1189 points.
# num of cell in the ghost penalty: 198
# Solving linear variational problem.
# 268/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 2879 nodes for 1440 points.
# num of cell in the ghost penalty: 246
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3787 nodes for 1894 points.
# 269/300:num of cell in the ghost penalty: 240
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 4041 nodes for 2021 points.
# 270/300:num of cell in the ghost penalty: 198
# Solving linear variational problem.
# 271/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 2851 nodes for 1426 points.
# num of cell in the ghost penalty: 216
# Solving linear variational problem.
# 272/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3277 nodes for 1639 points.
# num of cell in the ghost penalty: 218
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3627 nodes for 1814 points.
# 273/300:num of cell in the ghost penalty: 312
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 6561 nodes for 3281 points.
# 274/300:num of cell in the ghost penalty: 184
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 2501 nodes for 1251 points.
# 275/300:num of cell in the ghost penalty: 238
# Solving linear variational problem.
# 276/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 4155 nodes for 2078 points.
# num of cell in the ghost penalty: 214
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 277/300:Computed bounding box tree with 3599 nodes for 1800 points.
# num of cell in the ghost penalty: 242
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 278/300:Computed bounding box tree with 4279 nodes for 2140 points.
# num of cell in the ghost penalty: 324
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 279/300:Computed bounding box tree with 6913 nodes for 3457 points.
# num of cell in the ghost penalty: 250
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3563 nodes for 1782 points.
# 280/300:num of cell in the ghost penalty: 274
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 4263 nodes for 2132 points.
# 281/300:num of cell in the ghost penalty: 196
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 282/300:Computed bounding box tree with 2881 nodes for 1441 points.
# num of cell in the ghost penalty: 216
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3601 nodes for 1801 points.
# 283/300:num of cell in the ghost penalty: 200
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3029 nodes for 1515 points.
# 284/300:num of cell in the ghost penalty: 220
# Solving linear variational problem.
# 285/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3625 nodes for 1813 points.
# num of cell in the ghost penalty: 330
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 286/300:Computed bounding box tree with 7879 nodes for 3940 points.
# num of cell in the ghost penalty: 246
# Solving linear variational problem.
# 287/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 4519 nodes for 2260 points.
# num of cell in the ghost penalty: 242
# Solving linear variational problem.
# 288/300:Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3515 nodes for 1758 points.
# num of cell in the ghost penalty: 264
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 289/300:Computed bounding box tree with 4733 nodes for 2367 points.
# num of cell in the ghost penalty: 228
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 290/300:Computed bounding box tree with 3701 nodes for 1851 points.
# num of cell in the ghost penalty: 228
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3709 nodes for 1855 points.
# 291/300:num of cell in the ghost penalty: 184
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 292/300:Computed bounding box tree with 2497 nodes for 1249 points.
# num of cell in the ghost penalty: 200
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 293/300:Computed bounding box tree with 2909 nodes for 1455 points.
# num of cell in the ghost penalty: 214
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 294/300:Computed bounding box tree with 3371 nodes for 1686 points.
# num of cell in the ghost penalty: 230
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 295/300:Computed bounding box tree with 3791 nodes for 1896 points.
# num of cell in the ghost penalty: 274
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 296/300:Computed bounding box tree with 5291 nodes for 2646 points.
# num of cell in the ghost penalty: 268
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 297/300:Computed bounding box tree with 4985 nodes for 2493 points.
# num of cell in the ghost penalty: 200
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# 298/300:Computed bounding box tree with 2969 nodes for 1485 points.
# num of cell in the ghost penalty: 210
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 3215 nodes for 1608 points.
# 299/300:num of cell in the ghost penalty: 294
# Solving linear variational problem.
# Building point search tree to accelerate distance queries.
# Computed bounding box tree with 6155 nodes for 3078 points.
# np.shape(W_phi_fem)=(300, 64, 64)
# Epoch : 50
# Epoch : 100
# Epoch : 250
# Epoch : 500
# Epoch : 1000
# Epoch : 1500
# Epoch : 2000
# Epoch : 1910

# %%
j, k = 0, 0
fig, axes = plt.subplots(
    nb_rows,
    size_row,
    figsize=(size_per_fig * size_row, size_per_fig * nb_rows),
)

for i in range(len(indices)):
    if k == size_row:
        k = 0
        j += 1
    if epochs[indices[i]] == best_epoch:
        color = "firebrick"
    else:
        color = colors[2]
    sns.histplot(
        data=L2_errors_fno[indices[i]],
        kde=True,
        bins=30,
        color=color,
        edgecolor="k",
        log_scale=True,
        label=str(epochs[indices[i]]),
        stat="proportion",
        legend=True,
        ax=axes[j, k],
    )
    axes[j, k].set_xlabel("$L^2$ relative error")
    axes[j, k].legend()
    axes[j, k].set_xlim(1e-4, 2e-1)
    axes[j, k].set_ylim(0.0, 0.10)
    k += 1

plt.tight_layout()
if save_figs:
    plt.savefig(f"./images/histograms_new_data_L2.png")
plt.show()

# %%
palette = sns.cubehelix_palette(n_colors=7, start=0.25, rot=-0.25, gamma=0.5)
palette = palette.as_hex()
palette.append("#b22222")
palette = sns.color_palette(palette)

plt.figure(figsize=(10, 5))
errors_fno = np.array(L2_errors_fno[:])
print(np.shape(errors_fno))
dataframe = pd.DataFrame(errors_fno.transpose(), columns=epochs)

sns.boxplot(data=dataframe, palette=palette)
plt.xlabel("Training epochs")
plt.ylabel("$L^2$ relative error")
plt.yscale("log")
plt.grid(True, "both", "y")
plt.tight_layout()
if save_figs:
    plt.savefig(f"./images/boxplots_new_data_L2.png")
plt.show()
# Out:
# (8, 300)

# %%
L2_errors_fno = []

for j in epochs_means:
    print(f"Epoch : {j}")
    agent.model.load_weights(f"./models/model_{j}/model_weights")
    L2_error_fno = []
    X = generate_manual_new_data_numpy(Phi, F / data.max_norm_F, G)
    Y_pred = agent.model.call(X)

    domain = X[:, :, :, -1]
    nb_vert = np.shape(domain)[1]
    domain_prop = tf.reduce_sum(domain, axis=[1, 2]) / nb_vert**2
    diff = (
        W_phi_fem[:, :, :] * X[:, :, :, 1]
        + G
        - (Y_pred[:, :, :, 0] * X[:, :, :, 1] + G)
    )

    L2_error_fno = tf.sqrt(
        tf.reduce_mean(
            (diff**2) * X[:, :, :, -1] / (domain_prop[:, None, None]),
            axis=[1, 2],
        )
        / tf.reduce_mean(
            ((W_phi_fem * X[:, :, :, 1] + G) ** 2)
            * X[:, :, :, -1]
            / (domain_prop[:, None, None]),
            axis=[1, 2],
        )
    )

    L2_errors_fno.append(L2_error_fno)
# Out:
# Epoch : 40
# Epoch : 80
# Epoch : 120
# Epoch : 160
# Epoch : 200
# Epoch : 240
# Epoch : 280
# Epoch : 320
# Epoch : 360
# Epoch : 400
# Epoch : 440
# Epoch : 480
# Epoch : 520
# Epoch : 560
# Epoch : 600
# Epoch : 640
# Epoch : 680
# Epoch : 720
# Epoch : 760
# Epoch : 800
# Epoch : 840
# Epoch : 880
# Epoch : 920
# Epoch : 960
# Epoch : 1000
# Epoch : 1040
# Epoch : 1080
# Epoch : 1120
# Epoch : 1160
# Epoch : 1200
# Epoch : 1240
# Epoch : 1280
# Epoch : 1320
# Epoch : 1360
# Epoch : 1400
# Epoch : 1440
# Epoch : 1480
# Epoch : 1520
# Epoch : 1560
# Epoch : 1600
# Epoch : 1640
# Epoch : 1680
# Epoch : 1720
# Epoch : 1760
# Epoch : 1800
# Epoch : 1840
# Epoch : 1880
# Epoch : 1920
# Epoch : 1960
# Epoch : 2000
# Epoch : 1910

# %%
means = np.mean(L2_errors_fno, axis=1)
standard_deviation = np.std(L2_errors_fno, axis=1)
maxs = np.max(L2_errors_fno, axis=1)
mins = np.min(L2_errors_fno, axis=1)

plt.figure(figsize=(8, 3))
plt.subplot(1, 2, 1)
plt.semilogy(epochs_means[:-1], means[:-1], "-+", label="Mean")
plt.semilogy(
    epochs_means[:-1],
    standard_deviation[:-1],
    "-+",
    label="Standard deviation",
)
plt.semilogy(epochs_means[-1], means[-1], "x", c="firebrick", markersize=6)
plt.semilogy(
    epochs_means[-1], standard_deviation[-1], "x", c="firebrick", markersize=6
)
plt.xlabel("Epochs")
plt.grid(True, "both", "both")
plt.legend()

plt.subplot(1, 2, 2)
plt.semilogy(epochs_means[:-1], maxs[:-1], "-+", label="Maximum")
plt.semilogy(epochs_means[:-1], mins[:-1], "-+", label="Minimum")
plt.semilogy(epochs_means[-1], maxs[-1], "x", c="firebrick", markersize=6)
plt.semilogy(epochs_means[-1], mins[-1], "x", c="firebrick", markersize=6)
plt.grid(True, "both", "both")
plt.legend()
plt.xlabel("Epochs")
plt.ylabel("$L^2$ relative error")

plt.tight_layout()

if save_figs:
    plt.savefig(f"./images/min_mean_max_L2_error_epochs_new_data.png")
plt.show()
